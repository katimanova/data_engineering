# %% [markdown]
# ### Создание `единой базы`, хранящей структуру с путями

# %% [markdown]
# #### Подключение к диску, где хранятся все декомпозиции отчетов
# `192.168.137.76`

# %%
import os

import json
import random
from typing import List, Dict, Any

# %%
def build_hierarchical_structure(root_path):
    """
    Рекурсивно строит иерархическую структуру каталогов и файлов.
    Исключает дублирование, если имя папки совпадает с именем файла `.pdf`.
    Сортирует элементы в алфавитном порядке.
    """
    structure = {"name": os.path.basename(root_path), "children": []}
    try:
        items = sorted(os.listdir(root_path))  # Сортируем элементы по имени
        pdf_files = {os.path.splitext(f)[0]: f for f in items if f.endswith(".pdf")}
        for item in items:
            item_path = os.path.join(root_path, item)
            if os.path.isdir(item_path):
                if item.startswith("Декомпозиция_"):
                    # Если папка начинается с "Декомпозиция_", её пропускаем и обрабатываем содержимое
                    structure["children"].extend(build_hierarchical_structure(item_path)["children"])
                elif item in pdf_files:
                    # Если имя папки совпадает с именем PDF, добавляем только файл
                    structure["children"].append({
                        "name": item,
                        "path": os.path.join(root_path, pdf_files[item])
                    })
                else:
                    # Если это обычная папка, добавляем её как узел
                    sub_structure = build_hierarchical_structure(item_path)
                    # Проверяем вложенные элементы на дублирование
                    if len(sub_structure["children"]) == 1 and sub_structure["children"][0]["name"] == sub_structure["name"]:
                        # Если есть дубликат имени, заменяем узел только на файл
                        structure["children"].append(sub_structure["children"][0])
                    else:
                        structure["children"].append(sub_structure)
            elif item.endswith(".pdf") and os.path.splitext(item)[0] not in [c["name"] for c in structure["children"]]:
                # Если это PDF-файл, добавляем его, если его имя не совпадает с именем существующих узлов
                structure["children"].append({"name": os.path.splitext(item)[0], "path": item_path})
    except PermissionError:
        # Игнорируем папки без доступа
        pass
    return structure

# Путь к монтированной папке
remote_path = "/Volumes/gmvo/ai_pdf_store/Base_Books/"
hierarchical_structure = build_hierarchical_structure(remote_path)

output_file = os.path.join(os.getcwd(), "hierarchical_book_structure.json")
with open(output_file, "w", encoding="utf-8") as json_file:
    json.dump(hierarchical_structure, json_file, ensure_ascii=False, indent=4)

# %% [markdown]
# #### Обновление струкруты под задачу
# - из детей берется путь родителя и поднимается на уровень
# - очищаются именя разделов

# %%
# Список новых названий
new_titles = [
    "Общая характеристика речного бассейна",
    "Оценка экологического состояния и ключевые проблемы речного бассейна",
    "Целевые показатели",
    "Водохозяйственные балансы и балансы загрязняющих веществ",
    "Лимиты и квоты на забор воды из водных объектов и сброс сточных вод",
    "Перечень мероприятий по достижению целевого состояния речного бассейна"
]

def update_structure(node, titles):
    if 'children' in node:
        for child in node['children']:
            update_structure(child, titles)
        
        # Проверка и обновление структуры
        for child in node['children']:
            if node['name'] == child['name'].lstrip('._'):
                node['path'] = child['path']
                node['children'].remove(child)
                break

def reorder_structure(node, titles):
    if 'children' in node:
        for child in node['children']:
            reorder_structure(child, titles)
    
    # Переместить path после name
    if 'path' in node:
        reordered_node = {'name': node['name'], 'path': node['path']}
        if 'children' in node:
            reordered_node['children'] = node['children']
        node.clear()
        node.update(reordered_node)
    
    # Обновление имени
    node['name'] = node['name'].replace('_', ' ').lstrip('.').lstrip(' ').replace('  ', ' ').replace('й', 'й')    

    # Заменяем названия Книга 1...Книга 6 на новые
    if node['name'].startswith("Книга"):
        try:
            book_number = int(node['name'].split()[1])  # Извлекаем номер книги
            if 1 <= book_number <= len(titles):  # Проверяем, что номер в пределах списка
                node['name'] = titles[book_number - 1]
        except (IndexError, ValueError):
            pass  # Если не удаётся распознать номер, оставляем название без изменений

with open('hierarchical_book_structure.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Удаление первого уровня, если он не несет смысла
if 'children' in data and data['name'] == "":
    data = data['children']

# Обновление структуры
for node in data:
    update_structure(node, new_titles)
    reorder_structure(node, new_titles)

with open('hierarchical_structure.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Перезапись названий всех разделов
# Из "3 Перечень мероприятий по достижению целевого сост" -> "3 Перечень мероприятий по достижению целевого состояния речного бассейна"
# такие сокращения были ввиду невозможной записи полного названия в именя папок/файлов

# %%
def extract_titles_from_directory(directory):
    def extract_titles(data, titles):
        if isinstance(data, list):
            for item in data:
                extract_titles(item, titles)
        elif isinstance(data, dict):
            if 'title' in data:
                titles.append(data['title'])
            if 'subsections' in data:
                extract_titles(data['subsections'], titles)

    all_titles = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                    titles = []
                    extract_titles(data, titles)
                    all_titles.extend(titles)
    return all_titles

def update_names(node, titles):
    if 'children' in node:
        for child in node['children']:
            update_names(child, titles)
    
    if 'name' in node:
        for title in titles:
            if node['name'] in title:
                print(f"Updating name from '{node['name']}' to '{title}'")
                node['name'] = title
                break

# Список бассейнов и соответствующих директорий
basins = {
    "Бассейн Волга": '../../data/JSON/Волга/Исходные',
    "Бассейн Дон": '../../data/JSON/Дон/Исходные',
    "Бассейн Кубань": '../../data/JSON/Кубань/Исходные',
    "Бассейн Обь": '../../data/JSON/Обь/Исходные',
    "Бассейн Печора": '../../data/JSON/Печора/Исходные',
    "Бассейн Сура": '../../data/JSON/Сура/Исходные',
    "Бассейн Терек": '../../data/JSON/Терек/Исходные',
    "Бассейн Урал": '../../data/JSON/Урал/Исходные'
}

# Загрузка JSON файла
with open('hierarchical_structure.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Обработка каждого бассейна
for basin_name, directory_path in basins.items():
    # Извлечение titles из директории
    all_titles = extract_titles_from_directory(directory_path)
    all_titles = set(all_titles)

    print('____'* 20)
    print(all_titles)
    # Обновление имен в структуре
    for node in data:
        if node['name'] == basin_name:
            update_names(node, all_titles)

# Сохранение обновленного JSON файла
with open('hierarchical_structure.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)
# Out:
# ________________________________________________________________________________
# {'2.2.2 Качество воды по санитарно-микробиологическим показателям', '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги', '3.1. Выявление и формулировка проблем экологического состояния водных объектов', 'Российская Федерация', '6.3. Гидротехнические сооружения', '3.2.1. Наводнения.', '3.5.1. Ранжирование проблем', '3.1.1 Угроза наращивания темпов "цветения" водохранилищ цианобактериями (сине-зелеными водорослями).', '3.3. Водообеспеченность.', '2.2. Качество воды по пунктам наблюдений', 'ВВЕДЕНИЕ', 'Раздел 3. Институциональные мероприятия по достижению целевого состояния рассматриваемой территории Волжского бассейна на период 2011 – 2020 годы', '2.2 Расчетные водохозяйственные балансы для года 50% обеспеченности', '2.2.1. Природное качество вод – как целевой показатель состояния вод Волжского каскада водохранилищ.', 'Раздел 4. Мероприятия по улучшению оперативного управления по достижению целевого состояния рассматриваемой части бассейна р. Волги на период 2011 – 2020 годы', '6.1. Водоснабжение', '2.1.3. Сравнительная оценка качества вод водохранилищ Волжского каскада по биологическим показателям.', '2.1 Гидробиологическая характеристика водных объектов', 'Раздел 8. Социально-экономическая характеристика', '3. Основные проблемы бассейна р. Волги', '2.3. Распределение водных объектов по классам качества воды', '2.3.1.1. Современное состояние', 'Введение', '3.2.3 Год 95% обеспеченности', 'Раздел 6. Целевые показатели развития водохозяйственной инфраструктуры речного бассейна', '3.5. Ранжирование проблем по степени значимости, выделение основных проблем', 'Раздел 6.  Водные ресурсы', '2.3.1.1.8 Водохозяйственная инфраструктура', 'Раздел 4. Целевые показатели уменьшения негативных последствий наводнений и других видов негативного воздействия вод', '1 Гидрографическое и водохозяйственное районирование', 'Раздел 9. Использование водных ресурсов с изъятием стока', '3.2.3. Подтопление селитебных территорий и массивов земель сельскохозяйственного освоения', '3.3.1 Год 50% обеспеченности', '2.3.1.1.3 Водоотведение', 'Раздел 7.  Гидрогеологическая характеристика речного бассейна', '2.3.1.1.1 Социально-экономическая характеристика рассматриваемых территорий', '2.2.1.1 Гидрохимическая изученность', 'Раздел 7. Финансово-экономические и социально-экономические целевые показатели', '3.4.3. Проблемы управленческого характера', '2.2.1.3. Лимитирующие показатели качества воды', '2.1 Основные показатели каскада водохранилищ', '6.2. Водоотведение', '3.5.2. Список основных проблем бассейна р. Волги', 'Раздел 1.  Краткое описание природных условий', '2.3.1.2. Перспектива хозяйственного освоения бассейна р. Волга', '3.2. Выявление и формулировка проблем негативного воздействия вод', 'Раздел 15. Негативное воздействие вод', 'Раздел 5. Структурные мероприятия (по строительству и реконструкции сооружений) по достижению целевого состояния бассейна р. Волги на период 2011 – 2020 годы', '2.1.1. Преимущества биоиндикации в сравнении с гидрохимическим анализом качества поверхностных вод.', 'Раздел 4. Гидрологическая изученность', 'Раздел 10. Водохозяйственная инфраструктура', '3.3.3 Год 95 % обеспеченности', '3.4. Проблемы информационного, технологического и управленческого характера.', '2.2.2. Биологические критерии качества (классности) поверхностных вод.', '2.2.1.2. Ретроспективный анализ качества поверхностных вод', 'Раздел 6. Сводная ведомость требуемых финансовых затрат', '4. Балансы загрязняющих веществ в водных объектах речного бассейна', '2.3.1.1.5 Поступление загрязняющих веществ с рассредоточенным стоком', '3 Использование водных ресурсов с изъятием стока', '2. Экологическое состояние водных объектов', '2.1. Природное качество поверхностных вод бассейна р. Волга по гидробиологическим критериям', '3.2.1 Год 50% обеспеченности', '2.3. Гидрохимические целевые показатели качества воды', '2.1.2. Определение районов Чебоксарского водохранилища с природным качеством вод по структуре летнего фитопланктона 2011г.', '4.1 ...
# Updating name from 'Раздел 2. Ландшафты на территории бассейна' to 'Раздел 2. Ландшафты на территории бассейна'
# Updating name from 'Раздел 3. Водные объекты' to 'Раздел 3. Водные объекты'
# Updating name from 'Раздел 4. Гидрологическая изученность' to 'Раздел 4. Гидрологическая изученность'
# Updating name from 'Раздел 5. Гидрографическое и водохозяйственное районирование' to 'Раздел 5. Гидрографическое и водохозяйственное районирование'
# Updating name from 'Раздел 8. Социально-экономическая характеристика' to 'Раздел 8. Социально-экономическая характеристика'
# Updating name from 'Раздел 9. Использование водных ресурсов с изъятием стока' to 'Раздел 9. Использование водных ресурсов с изъятием стока'
# Updating name from 'Раздел 10. Водохозяйственная инфраструктура' to 'Раздел 10. Водохозяйственная инфраструктура'
# Updating name from '11.1 Изменение количественных показателей рыбного промысла' to '11.1 Изменение количественных показателей рыбного промысла'
# Updating name from '11.2 Товарное рыбоводство' to '11.2 Товарное рыбоводство'
# Updating name from 'Раздел 12. Гидроэнергетика' to 'Раздел 12. Гидроэнергетика'
# Updating name from 'Раздел 13. Водный транспорт' to 'Раздел 13. Водный транспорт'
# Updating name from 'Раздел 15. Негативное воздействие вод' to 'Раздел 15. Негативное воздействие вод'
# Updating name from 'Введение' to 'Введение'
# Updating name from '1. Идентификация водных объектов на территории рассматриваемого речного бассейна и их категорирование' to '1. Идентификация водных объектов на территории рассматриваемого речного бассейна и их категорирование'
# Updating name from '2.1 Гидробиологическая характеристика водных объектов' to '2.1 Гидробиологическая характеристика водных объектов'
# Updating name from '2.2.1.1 Гидрохимическая изученность' to '2.2.1.1 Гидрохимическая изученность'
# Updating name from '2.2.1.2. Ретроспективный анализ качества поверхностных вод' to '2.2.1.2. Ретроспективный анализ качества поверхностных вод'
# Updating name from '2.2.1.3. Лимитирующие показатели качества воды' to '2.2.1.3. Лимитирующие показатели качества воды'
# Updating name from '2.2.1.4. Природные показатели качества воды местного стока' to '2.2.1.4. Природные показатели качества воды местного стока'
# Updating name from '2.2.1.5. Концентрации загрязняющих веществ по акваториям' to '2.2.1.5. Концентрации загрязняющих веществ по акваториям'
# Updating name from '2.2.1. Качество воды по химическим показателям' to '2.2.1. Качество воды по химическим показателям'
# Updating name from '2.2.2 Качество воды по санитарно-микробиологическим показателям' to '2.2.2 Качество воды по санитарно-микробиологическим показателям'
# Updating name from '2.2. Качество воды по пунктам наблюдений' to '2.2. Качество воды по пунктам наблюдений'
# Updating name from '2.3.1.1.1 Социально-экономическая характеристика рассматриваемых территорий' to '2.3.1.1.1 Социально-экономическая характеристика рассматриваемых территорий'
# Updating name from '2.3.1.1.2 Водопотребление' to '2.3.1.1.2 Водопотребление'
# Updating name from '2.3.1.1.3 Водоотведение' to '2.3.1.1.3 Водоотведение'
# Updating name from '2.3.1.1.4. Поступление загрязняющих веществ с сосредоточенным стоком' to '2.3.1.1.4. Поступление загрязняющих веществ с сосредоточенным стоком'
# Updating name from '2.3.1.1.5 Поступление загрязняющих веществ с рассредоточенным стоком' to '2.3.1.1.5 Поступление загрязняющих веществ с рассредоточенным стоком'
# Updating name from '2.3.1.1.6 Использование акваторий водных объектов' to '2.3.1.1.6 Использование акваторий водных объектов'
# Updating name from '2.3.1.1.7 Регулирование водного стока' to '2.3.1.1.7 Регулирование водного стока'
# Updating name from '2.3.1.1.8 Водохозяйственная инфраструктура' to '2.3.1.1.8 Водохозяйственная инфраструктура'
# Updating name from '2.3.1.1. Современное состояние' to '2.3.1.1. Современное состояние'
# Updating name from '2.3.1.2. Перспектива хозяйственного освоения бассейна р. Волга' to '2.3.1.2. Перспектива хозяйственного освоения бассейна р. Волга'
# Updating name from '2.3.1.3 Соблюдение НДВ в современных условиях' to '2.3.1.3 Соблюдение НДВ в современных условиях'
# Updating name from '2.3.1. Антропогенная нагрузка на водные объекты' to '2.3.1. Антропогенная нагрузка на водные объекты'
# Updating name from '2.3.2 Поле концентраций загрязняющих веществ' to '2.3.2 Поле концентраций загрязняющих веществ'
# Updating name from '2.3.3 Классы качества воды рассматриваемых водных объектов' to '2.3.3 Классы качества воды рассматриваемых водных объектов'
# Updating name from '2.3. Распределение водных объектов по классам качества воды' to '2.3. Распределение водных объектов по классам качества воды'
# Updating name from '2. Экологическое состояние водных объектов' to '2. Экологическое состояние водных объектов'
# Updating name from '3.1.2. Негативные последствия зарегулирования Волги для рыбохозяйственного водопользования' to '3.1.2. Негативные последствия зарегулирования Волги для рыбохозяйственного водопользования'
# Updating name from '3.1.3. Снижение потребительских качеств вод.' to '3.1.3. Снижение потребительских качеств вод.'
# Updating name from '3.1. Выявление и формулировка проблем экологического состояния водных объектов' to '3.1. Выявление и формулировка проблем экологического состояния водных объектов'
# Updating name from '3.2.1. Наводнения.' to '3.2.1. Наводнения.'
# Updating name from '3.2.2. Абразия берегов водохранилищ.' to '3.2.2. Абразия берегов водохранилищ.'
# Updating name from '3.2.3. Подтопление селитебных территорий и массивов земель сельскохозяйственного освоения' to '3.2.3. Подтопление селитебных территорий и массивов земель сельскохозяйственного освоения'
# Updating name from '3.2.4. Эрозия почв' to '3.2.4. Эрозия почв'
# Updating name from '3.2. Выявление и формулировка проблем негативного воздействия вод' to '3.2. Выявление и формулировка проблем негативного воздействия вод'
# Updating name from '3.3. Водообеспеченность.' to '3.3. Водообеспеченность.'
# Updating name from '3.4.1. Проблемы информационного характера.' to '3.4.1. Проблемы информационного характера.'
# Updating name from '3.4.2. Проблемы технологического характера.' to '3.4.2. Проблемы технологического характера.'
# Updating name from '3.4.3. Проблемы управленческого характера' to '3.4.3. Проблемы управленческого характера'
# Updating name from '3.4. Проблемы информационного, технологического и управленческого характера.' to '3.4. Проблемы информационного, технологического и управленческого характера.'
# Updating name from '3.5.1. Ранжирование проблем' to '3.5.1. Ранжирование проблем'
# Updating name from '3.5.2. Список основных проблем бассейна р. Волги' to '3.5.2. Список основных проблем бассейна р. Волги'
# Updating name from '3.5. Ранжирование проблем по степени значимости, выделение основных проблем' to '3.5. Ранжирование проблем по степени значимости, выделение основных проблем'
# Updating name from '3. Основные проблемы бассейна р. Волги' to '3. Основные проблемы бассейна р. Волги'
# Updating name from 'Введение' to 'Введение'
# Updating name from 'Список использованных материалов' to 'Список использованных материалов'
# Updating name from '2.1.1. Преимущества биоиндикации в сравнении с гидрохимическим анализом качества поверхностных вод.' to '2.1.1. Преимущества биоиндикации в сравнении с гидрохимическим анализом качества поверхностных вод.'
# Updating name from '2.1.2. Определение районов Чебоксарского водохранилища с природным качеством вод по структуре летнего фитопланктона 2011г.' to '2.1.2. Определение районов Чебоксарского водохранилища с природным качеством вод по структуре летнего фитопланктона 2011г.'
# Updating name from '2.1.3. Сравнительная оценка качества вод водохранилищ Волжского каскада по биологическим показателям.' to '2.1.3. Сравнительная оценка качества вод водохранилищ Волжского каскада по биологическим показателям.'
# Updating name from '2.1. Природное качество поверхностных вод бассейна р. Волга по гидробиологическим критериям' to '2.1. Природное качество поверхностных вод бассейна р. Волга по гидробиологическим критериям'
# Updating name from '2.2.1. Природное качество вод – как целевой показатель состояния вод Волжского каскада водохранилищ.' to '2.2.1. Природное качество вод – как целевой показатель состояния вод Волжского каскада водохранилищ.'
# Updating name from '2.2.2. Биологические критерии качества (классности) поверхностных вод.' to '2.2.2. Биологические критерии качества (классности) поверхностных вод.'
# Updating name from '2.2. Биологические целевые показатели качества воды' to '2.2. Биологические целевые показатели качества воды'
# Updating name from '2.3. Гидрохимические целевые показатели качества воды' to '2.3. Гидрохимические целевые показатели качества воды'
# Updating name from 'Раздел 2. Целевые показатели качества воды в водных объектах речного бассейна' to 'Раздел 2. Целевые показатели качества воды в водных объектах речного бассейна'
# Updating name from '3.1. Характеристика существующей системы мониторинга состояния поверхностных водных объектов' to '3.1. Характеристика существующей системы мониторинга состояния поверхностных водных объектов'
# Updating name from '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги' to '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги'
# Updating name from 'Раздел 3. Целевые показатели развития системы государственного мониторинга водных объектов речного бассейна' to 'Раздел 3. Целевые показатели развития системы государственного мониторинга водных объектов речного бассейна'
# Updating name from '4.1. Основные целевые показатели уменьшения негативных последствий наводнений' to '4.1. Основные целевые показатели уменьшения негативных последствий наводнений'
# Updating name from '4.2. Целевые показатели уменьшения последствий деформации русел рек' to '4.2. Целевые показатели уменьшения последствий деформации русел рек'
# Updating name from 'Раздел 4. Целевые показатели уменьшения негативных последствий наводнений и других видов негативного воздействия вод' to 'Раздел 4. Целевые показатели уменьшения негативных последствий наводнений и других видов негативного воздействия вод'
# Updating name from 'Раздел 5. Целевые показатели водообеспечения населения и объектов экономики речного бассейна' to 'Раздел 5. Целевые показатели водообеспечения населения и объектов экономики речного бассейна'
# Updating name from 'Российская Федерация' to 'Российская Федерация'
# Updating name from '6.1. Водоснабжение' to '6.1. Водоснабжение'
# Updating name from '6.2. Водоотведение' to '6.2. Водоотведение'
# Updating name from '6.3. Гидротехнические сооружения' to '6.3. Гидротехнические сооружения'
# Updating name from 'Раздел 6. Целевые показатели развития водохозяйственной инфраструктуры речного бассейна' to 'Раздел 6. Целевые показатели развития водохозяйственной инфраструктуры речного бассейна'
# Updating name from 'Раздел 7. Финансово-экономические и социально-экономические целевые показатели' to 'Раздел 7. Финансово-экономические и социально-экономические целевые показатели'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'Список использованных материалов' to 'Список использованных материалов'
# Updating name from '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги' to '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги'
# Updating name from '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги' to '3.2. Целевые показатели развития системы мониторинговых наблюдений в бассейне р. Волги'
# Updating name from '1 Гидрографическое и водохозяйственное районирование' to '1 Гидрографическое и водохозяйственное районирование'
# Updating name from '2.1 Основные показатели каскада водохранилищ' to '2.1 Основные показатели каскада водохранилищ'
# Updating name from '2.2 Расчетные водохозяйственные балансы для года 50% обеспеченности' to '2.2 Расчетные водохозяйственные балансы для года 50% обеспеченности'
# Updating name from '2.3 Расчетные водохозяйственные балансы для года 75% обеспеченности' to '2.3 Расчетные водохозяйственные балансы для года 75% обеспеченности'
# Updating name from '2.4 Расчетные водохозяйственные балансы для года 95% обеспеченности' to '2.4 Расчетные водохозяйственные балансы для года 95% обеспеченности'
# Updating name from '2. Водохозяйственные балансы р. Волги в створах гидроузлов' to '2. Водохозяйственные балансы р. Волги в створах гидроузлов'
# Updating name from '3.1. Методика расчетов' to '3.1. Методика расчетов'
# Updating name from '3.2.1 Год 50% обеспеченности' to '3.2.1 Год 50% обеспеченности'
# Updating name from '3.2.2 Год 75% обеспеченности' to '3.2.2 Год 75% обеспеченности'
# Updating name from '3.2.3 Год 95% обеспеченности' to '3.2.3 Год 95% обеспеченности'
# Updating name from '3.2 Современное водопользование' to '3.2 Современное водопользование'
# Updating name from '3.3.1 Год 50% обеспеченности' to '3.3.1 Год 50% обеспеченности'
# Updating name from '3.3.2 Год 75 % обеспеченности' to '3.3.2 Год 75 % обеспеченности'
# Updating name from '3.3.3 Год 95 % обеспеченности' to '3.3.3 Год 95 % обеспеченности'
# Updating name from '3.3 Перспективное водопользование на 2020 год' to '3.3 Перспективное водопользование на 2020 год'
# Updating name from '3. Водохозяйственные балансы притоков р. Волги' to '3. Водохозяйственные балансы притоков р. Волги'
# Updating name from '4. Балансы загрязняющих веществ в водных объектах речного бассейна' to '4. Балансы загрязняющих веществ в водных объектах речного бассейна'
# Updating name from 'Введение' to 'Введение'
# Updating name from '1 Водные объекты и водохозяйственные участки' to '1 Водные объекты и водохозяйственные участки'
# Updating name from '2 Водные ресурсы' to '2 Водные ресурсы'
# Updating name from '3 Использование водных ресурсов с изъятием стока' to '3 Использование водных ресурсов с изъятием стока'
# Updating name from '4 Лимиты и квоты на 2010-2012 годы, утвержденные Федеральным агентством водных ресурсов' to '4 Лимиты и квоты на 2010-2012 годы, утвержденные Федеральным агентством водных ресурсов'
# Updating name from '5 Предложение по лимитам и квотам забора и сброса на 2015 и 2020 годы' to '5 Предложение по лимитам и квотам забора и сброса на 2015 и 2020 годы'
# Updating name from 'Введение' to 'Введение'
# Updating name from 'Раздел 1. Водная стратегия Российской Федерации и ключевые проблемы бассейна реки Волги' to 'Раздел 1. Водная стратегия Российской Федерации и ключевые проблемы бассейна реки Волги'
# Updating name from 'Раздел 2. Фундаментальные мероприятия по достижению целевого состояния рассматриваемой территории бассейна р. Волги на период 2011 – 2020 годы' to 'Раздел 2. Фундаментальные мероприятия по достижению целевого состояния рассматриваемой территории бассейна р. Волги на период 2011 – 2020 годы'
# Updating name from 'Раздел 3. Институциональные мероприятия по достижению целевого состояния рассматриваемой территории Волжского бассейна на период 2011 – 2020 годы' to 'Раздел 3. Институциональные мероприятия по достижению целевого состояния рассматриваемой территории Волжского бассейна на период 2011 – 2020 годы'
# Updating name from 'Раздел 4. Мероприятия по улучшению оперативного управления по достижению целевого состояния рассматриваемой части бассейна р. Волги на период 2011 – 2020 годы' to 'Раздел 4. Мероприятия по улучшению оперативного управления по достижению целевого состояния рассматриваемой части бассейна р. Волги на период 2011 – 2020 годы'
# Updating name from 'Раздел 5. Структурные мероприятия (по строительству и реконструкции сооружений) по достижению целевого состояния бассейна р. Волги на период 2011 – 2020 годы' to 'Раздел 5. Структурные мероприятия (по строительству и реконструкции сооружений) по достижению целевого состояния бассейна р. Волги на период 2011 – 2020 годы'
# Updating name from 'Раздел 6. Сводная ведомость требуемых финансовых затрат' to 'Раздел 6. Сводная ведомость требуемых финансовых затрат'
# Updating name from 'Раздел 7. Календарный план-график реализации и финансирования мероприятий' to 'Раздел 7. Календарный план-график реализации и финансирования мероприятий'
# Updating name from 'Введение' to 'Введение'
# Updating name from 'Список использованных материалов' to 'Список использованных материалов'
# ________________________________________________________________________________
# {'Таблица 8.2 - Участок II: г.Задонск – г.Лиски, млн.м3', '6 ВОДОХОЗЯЙСТВЕННЫЙ БАЛАНС БАССЕЙНА р.ДОН ПО КАЛЕНДАРНЫМ РЯДАМ ВОССТАНОВЛЕННОГО СТОКА. УРОВЕНЬ 2015 г., ВАРИАНТ В2', 'Таблица 13.19 - Сводные показатели водохозяйственного баланса по участку 05.01.03.008 - р.Чир, млн.м3', '2.4.3 Структурные мероприятия (по строительству и реконструкции сооружений)', '1.1.5 Специфические загрязняющие вещества', '4.2 Гидрогеологическая характеристика речного басейна', '5.5.1 Водохозяйственный комплекс и использование водных ресурсов в бассейне', 'Таблица 10.3 - Участок III: г.Лиски – г.Павловск, млн.м3', '5.5 Районирование территории бассейна по степени паводковой опасности', '2.2 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока в бассейне', 'Таблица 7.6 - Участок VI: г.Калач-на-Дону – Цимлянский ГУ, млн.м3', 'Таблица 6.2 - Участок II: г.Задонск – г.Лиски, млн.м3', 'Таблица 16.7 - Донской магистральный канал, млн.м3', 'Таблица 14.2 - Водохозяйственный баланс Цимлянского водохранилища для года близкого к году 75% обеспеченности (1965/1966 г.)', 'Таблица 7.9 - Участок VIII: выше впадения р.Северский Донец – устье, млн.м3', '2.8 Перечень мероприятий по достижению целевого состояния бассейна р. Дон, Белгородская область', 'Таблица 17.3 - Участок III: г.Лиски – г.Павловск, млн.м3', 'Таблица 10.1 - Участок I: исток - г.Задонск, млн.м3', 'Таблица 17.6 - Участок VI: г.Калач-на-Дону – Цимлянский ГУ, млн.м3', '3.3.1 Факторы формирования качества подземных вод', 'Таблица 5.7 - Донской магистральный канал, млн.м3', '3 Квоты забора (изъятия) водных ресурсов из водных объектов и сброса сточных вод,                                    соответствующих нормативам качества. Бассейн р. Дон, уровень 2015 г., тыс. м3', 'Таблица 13.17 - Сводные показатели водохозяйственного баланса по участку 05.01.03.003 - р.Медведица от впадения р.Терса до устья, млн.м3', '2.2 Перечень мероприятий по достижению целевого состояния бассейна р.Дон, Орловская область', 'Таблица 14.12 - Водохозяйственный баланс Старооскольского водохранилища для года 95% обеспеченности по стоку', 'Таблица 13.27 - Сводные показатели водохозяйственного баланса по участку 05.01.05.001 - р.Сал, млн.м3', 'Таблица 18.4 - Участок IV: г.Павловск – выше впадения р.Хопер, млн.м3', 'Зона полупустынной или полынно-типчаковой степи.', '2.4.6 Оценка вероятных воздействий реализации мероприятий Схемы на окружающую среду', '18 ВОДОХОЗЯЙСТВЕННЫЙ БАЛАНС БАССЕЙНА р.ДОН ДЛЯ МНОГОВОДНЫХ ГРУППИРОВОК ЛЕТ. УРОВЕНЬ 2020г, ВАРИАНТ С', 'Таблица 18.8 - Участок VII: Цимлянский ГУ – выше впадения р.Северский Донец, млн.м3', '4.1.1 Прогнозные ресурсы и эксплуатационные запасы подземных вод', '3 ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ПОДЗЕМНЫХ ВОДНЫХ   ОБЪЕКТОВ НА ТЕРРИТОРИИ БАССЕЙНА р.ДОН', '3 Сводные показатели Программы мероприятий по достижению целевого состояния бассейна р.Дон', '2.3.2 Мероприятия по улучшению оперативного управления', '6 ПЕРЕЧЕНЬ ВОДНЫХ ОБЪЕКТОВ БАССЕЙНА р.ДОН И ИХ ЧАСТЕЙ, ОСУЩЕСТВЛЕНИЕ МЕР ПО ОХРАНЕ И ПРЕДОТВРАЩЕНИЮ НЕГАТИВНОГО ВОЗДЕЙСТВИЯ ВОД И ЛИКВИДАЦИИ ЕГО ПОСЛЕДСТВИЙ В ОТНОШЕНИЕ КОТОРЫХ ВОЗЛОЖЕНО НА ОРГАНЫ ГОСУДАРСТВЕННОЙ ВЛАСТИ РОССИЙСКОЙ ФЕДЕРАЦИИ И ОРГАНЫ ГОСУДАРСТВЕННОЙ ВЛАСТИ СУБЪЕКТОВ РОССИЙСКОЙ ФЕДЕРАЦИИ', 'Таблица 16.1 - Участок I: исток - г.Задонск, млн.м3', 'Таблица 13.24 - Сводные показатели водохозяйственного баланса по участку 05.01.04.005 - р.Северский Донец от границы РФ с Украиной до впадения р.Калитва, млн.м3', '2.11.5 Календарный план-график реализации и финансирования мероприятий по достижению целевого состояния бассейна', '10 ВОДОХОЗЯЙСТВЕННЫЙ БАЛАНС БАССЕЙНА р.ДОН ПО КАЛЕНДАРНЫМ РЯДАМ ВОССТАНОВЛЕННОГО СТОКА. УРОВЕНЬ 2020 г., ВАРИАНТ С1', '2.5.1 Институциональные мероприятия', 'Таблица 11.4 - Участок IV: г.Павловск – выше впадения р.Хопер, млн.м3', '2.3 Региональные особенности изменчивости структурной организации гидробиоценоза р.Дон', 'Таблица 3.3 - Участок III: г.Лиски – г.Павловск, млн.м3', 'Таблица 14.13 - Водохозяйственный баланс Пролетарского водохрани ...
# Updating name from '1.1 Территория' to '1.1 Территория'
# Updating name from '1.2 Рельеф. Гидрография' to '1.2 Рельеф. Гидрография'
# Updating name from '1.3 Геоморфология' to '1.3 Геоморфология'
# Updating name from '1.4 Почвенный покров' to '1.4 Почвенный покров'
# Updating name from '1.5 Климат' to '1.5 Климат'
# Updating name from '1 Физико-географическое описание речного бассейна' to '1 Физико-географическое описание речного бассейна'
# Updating name from '2.1 Прогноз основных показателей долгосрочного соц' to '2.1 Прогноз основных показателей долгосрочного социально-экономического развития территории бассейна р.Дон до 2020 г.'
# Updating name from '2 СОЦИАЛЬНО-ЭКОНОМИЧЕСКАЯ ХАРАКТЕРИСТИКА ТЕРРИТОРИ' to '2 СОЦИАЛЬНО-ЭКОНОМИЧЕСКАЯ ХАРАКТЕРИСТИКА ТЕРРИТОРИИ РЕЧНОГО БАССЕЙНА'
# Updating name from '3.1 Гидрологическая изученность' to '3.1 Гидрологическая изученность'
# Updating name from '3.2 Водохозяйственное районирование территории бас' to '3.2 Водохозяйственное районирование территории бассейна р.Дон'
# Updating name from '3.3.1 Водный режим рек' to '3.3.1 Водный режим рек'
# Updating name from '3.3.2 Годовой сток' to '3.3.2 Годовой сток'
# Updating name from '3.3.3 Внутригодовое распределение стока' to '3.3.3 Внутригодовое распределение стока'
# Updating name from '3.3.4 Минимальные расходы воды' to '3.3.4 Минимальные расходы воды'
# Updating name from '3.3.5 Сток весеннего половодья' to '3.3.5 Сток весеннего половодья'
# Updating name from '3.3 Гидрологическая характеристика речного бассейн' to '3.3 Гидрологическая характеристика речного бассейна'
# Updating name from '3 ПОВЕРХНОСТНЫЕ ВОДНЫЕ РЕСУРСЫ' to '3 ПОВЕРХНОСТНЫЕ ВОДНЫЕ РЕСУРСЫ'
# Updating name from '4.1.1 Прогнозные ресурсы и эксплуатационные запасы' to '4.1.1 Прогнозные ресурсы и эксплуатационные запасы подземных вод'
# Updating name from '4.1.2 Состояние системы мониторинга подземных вод' to '4.1.2 Состояние системы мониторинга подземных вод'
# Updating name from '4.1 Гидрогеологическая изученность речного бассейн' to '4.1 Гидрогеологическая изученность речного бассейна'
# Updating name from '4.2.1 Гидрогеологические условия' to '4.2.1 Гидрогеологические условия'
# Updating name from '4.2.2 Защищенность подземных вод от загрязнения' to '4.2.2 Защищенность подземных вод от загрязнения'
# Updating name from '4.2 Гидрогеологическая характеристика речного басе' to '4.2 Гидрогеологическая характеристика речного басейна'
# Updating name from '4.3 Характеристика хозяйственного освоения ресурсо' to '4.3 Характеристика хозяйственного освоения ресурсов пресных подземных вод'
# Updating name from '4.4 Использование подземных вод' to '4.4 Использование подземных вод'
# Updating name from '4 Подземные воды' to '4 Подземные воды'
# Updating name from '5.1 Природные зоны и ландшафты бассейна р. Дон' to '5.1 Природные зоны и ландшафты бассейна р. Дон'
# Updating name from 'Белгородская область' to '2.8 Перечень мероприятий по достижению целевого состояния бассейна р. Дон, Белгородская область'
# Updating name from 'Белгородский район' to 'Белгородский район:'
# Updating name from 'Валуйский район' to 'Валуйский район:'
# Updating name from 'Волгоградская область' to 'Волгоградская область'
# Updating name from 'Воронежская область' to 'Воронежская область'
# Updating name from 'Липецкая область' to 'Липецкая область'
# Updating name from 'На территории Ставропольского края в пределах басс' to 'На территории Ставропольского края в пределах бассейна р.Дон создано 6 государственных природных заказников:'
# Updating name from 'Особо охраняемые природные территории бассейна р. ' to 'Особо охраняемые природные территории бассейна р. Дон регионального подчинения.'
# Updating name from 'Региональные природные парки' to 'Региональные природные парки:'
# Updating name from 'Ростовская область' to 'Ростовская область'
# Updating name from 'Сеть ООПТ регионального значения находящихся в пре' to 'Сеть ООПТ регионального значения находящихся в пределах бассейна на территории области включает 2 природных парка, 14 заказников, 9 памятников природы.'
# Updating name from 'Ставропольский край' to 'Ставропольский край'
# Updating name from 'Шебекинский район' to 'Шебекинский район:'
# Updating name from '5.2 Особо охраняемые природные территории бассейна' to '5.2 Особо охраняемые природные территории бассейна'
# Updating name from '5.3.1 Дельта Дона' to '5.3.1 Дельта Дона'
# Updating name from '5.3.2 Веселовское водохранилище' to '5.3.2 Веселовское водохранилище'
# Updating name from '5.3.3 Озеро Маныч-Гудило' to '5.3.3 Озеро Маныч-Гудило'
# Updating name from '5.3 Рамсарские угодья в бассейне р.Дон' to '5.3 Рамсарские угодья в бассейне р.Дон'
# Updating name from '5.4 Техническая схема регулирования и распределени' to '5.4 Техническая схема регулирования и распределения водных ресурсов'
# Updating name from '5.5.1 Водохозяйственный комплекс и использование в' to '5.5.1 Водохозяйственный комплекс и использование водных ресурсов в бассейне'
# Updating name from '5.5.2 Водоснабжение' to '5.5.2 Водоснабжение'
# Updating name from '5.5.3 Орошение земель' to '5.5.3 Орошение земель'
# Updating name from '5.5.4 Водный транспорт' to '5.5.4 Водный транспорт'
# Updating name from '5.5.5 Рыбное хозяйство' to '5.5.5 Рыбное хозяйство'
# Updating name from '5.5.6 Гидроэнергетика' to '5.5.6 Гидроэнергетика'
# Updating name from '5.5 Характеристика использования водных объектов' to '5.5 Характеристика использования водных объектов'
# Updating name from '5.6 Сводные показатели использования водных ресурс' to '5.6 Сводные показатели использования водных ресурсов в бассейне р.Дон на современном уровне'
# Updating name from 'Зона полупустынной или полынно-типчаковой степи' to 'Зона полупустынной или полынно-типчаковой степи.'
# Updating name from '5 Характеристика хозяйственного освоения бассейна ' to '5 Характеристика хозяйственного освоения бассейна и существующей водохозяйственной инфраструктуры'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from '1.1.1 Характеристика исходной информации' to '1.1.1 Характеристика исходной информации'
# Updating name from '1.1.2 Минерализация и главные ионы' to '1.1.2 Минерализация и главные ионы'
# Updating name from '1.1.3 Газовый режим' to '1.1.3 Газовый режим'
# Updating name from '1.1.4 Органические и биогенные вещества' to '1.1.4 Органические и биогенные вещества'
# Updating name from '1.1.5 Специфические загрязняющие вещества' to '1.1.5 Специфические загрязняющие вещества'
# Updating name from '1.1.6 Комплексная оценка качества воды р.Дон и его' to '1.1.6 Комплексная оценка качества воды р.Дон и его основных притоков'
# Updating name from '1.1 Оценка состояния р. Дон и его основных притоко' to '1.1 Оценка состояния р. Дон и его основных притоков по гидрохимическим показателям'
# Updating name from '1.2 Обобщенная оценка качества воды в бассейне р.Д' to '1.2 Обобщенная оценка качества воды в бассейне р.Дон по удельному комбинаторному индексу загрязненности воды (УКИЗВ)'
# Updating name from '1.3.1 Оценка влияния сосредоточенных источников за' to '1.3.1 Оценка влияния сосредоточенных источников загрязняющих веществ на качество воды в р.Дон'
# Updating name from '1.3.2 Оценка возможного влияния рассредоточенных (' to '1.3.2 Оценка возможного влияния рассредоточенных (диффузных) источников загрязняющих веществ на качество воды водных объектов в бассейне р.Дон'
# Updating name from '1.3 Источники загрязнения и химический состав вод' to '1.3 Источники загрязнения и химический состав вод'
# Updating name from '1.4 Оценка соответствия качества воды водных объек' to '1.4 Оценка соответствия качества воды водных объектов бассейна р.Дон требованиям рыбохозяйственного, питьевого и коммунально-бытового использования'
# Updating name from '1 ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ВОДНЫХ ОБЪЕКТОВ ' to '1 ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ВОДНЫХ ОБЪЕКТОВ           БАССЕЙНА р.ДОН'
# Updating name from '2.1 Пространственно-временная изменчивость загрязн' to '2.1 Пространственно-временная изменчивость загрязненности Нижнего Дона'
# Updating name from '2.2 Региональные особенности изменчивости компонен' to '2.2 Региональные особенности изменчивости компонентного состава водной среды нижнего течения р.Дон'
# Updating name from '2.3 Региональные особенности изменчивости структур' to '2.3 Региональные особенности изменчивости структурной организации гидробиоценоза р.Дон'
# Updating name from '2.4 Характер изменчивости состояния экосистемы Ниж' to '2.4 Характер изменчивости состояния экосистемы Нижнего Дона'
# Updating name from '2.5 Общая характеристика притока растворенных хими' to '2.5 Общая характеристика притока растворенных химических веществ на устьевой участок р.Дон'
# Updating name from '2.6 Экологически допустимые уровни антропогенного ' to '2.6 Экологически допустимые уровни антропогенного воздействия на экосистему Нижнего Дона'
# Updating name from '2 ИНТЕГРАЛЬНАЯ ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ НИЖ' to '2 ИНТЕГРАЛЬНАЯ ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ НИЖНЕГО ДОНА'
# Updating name from '3.1 Экологическое состояние подземных водных объек' to '3.1 Экологическое состояние подземных водных объектов речного бассейна'
# Updating name from '3.2.1 Состояние подземных вод в районах интенсивно' to '3.2.1 Состояние подземных вод в районах интенсивной их добычи для водоснабжения населения'
# Updating name from '3.2.2 Состояние подземных вод в районах разработки' to '3.2.2 Состояние подземных вод в районах разработки месторождений твердых полезных ископаемых'
# Updating name from '3.2 Гидродинамические условия' to '3.2 Гидродинамические условия'
# Updating name from '3.3.1 Факторы формирования качества подземных вод' to '3.3.1 Факторы формирования качества подземных вод'
# Updating name from '3.3.2 Загрязнение подземных вод' to '3.3.2 Загрязнение подземных вод'
# Updating name from '3.3.3 Загрязнение на водозаборах подземных вод' to '3.3.3 Загрязнение на водозаборах подземных вод'
# Updating name from '3.3.4 Участки загрязнения подземных вод' to '3.3.4 Участки загрязнения подземных вод'
# Updating name from '3.3 Качество подземных вод' to '3.3 Качество подземных вод'
# Updating name from '3.4 Особенности организации наблюдений за качество' to '3.4 Особенности организации наблюдений за качеством подземных вод в бассейне р.Дон'
# Updating name from '3 ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ПОДЗЕМНЫХ ВОДНЫХ' to '3 ОЦЕНКА ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ПОДЗЕМНЫХ ВОДНЫХ   ОБЪЕКТОВ НА ТЕРРИТОРИИ БАССЕЙНА р.ДОН'
# Updating name from '4.1 Техническая схема регулирования и распределени' to '4.1 Техническая схема регулирования и распределения водных ресурсов'
# Updating name from '4.2 Использование водных объектов' to '4.2 Использование водных объектов'
# Updating name from '4.3 Оценка обеспеченности водными ресурсами населе' to '4.3 Оценка обеспеченности водными ресурсами населения и экономики бассейна на современном уровне развития водохозяйственного комплекса'
# Updating name from '4.4 Прогнозные показатели использования водных рес' to '4.4 Прогнозные показатели использования водных ресурсов в бассейне р.Дон на уровнях 2015, 2020 гг.'
# Updating name from '4.5 Оценка обеспеченности населения и экономики ба' to '4.5 Оценка обеспеченности населения и экономики бассейна водными ресурсами на уровнях 2015, 2020 гг.'
# Updating name from '5.1 Основные виды негативного воздействия вод в ба' to '5.1 Основные виды негативного воздействия вод в бассейне р.Дон и причины их возникновения'
# Updating name from '5.2.1 Затопление освоенных территорий на Верхнем Д' to '5.2.1 Затопление освоенных территорий на Верхнем Дону'
# Updating name from '5.2.2 Затопление освоенных территорий на Нижнем До' to '5.2.2 Затопление освоенных территорий на Нижнем Дону'
# Updating name from '5.2 Негативное воздействие вод связанное с затопле' to '5.2 Негативное воздействие вод связанное с затоплением хозяйственно-освоенных территорий половодьями и паводками в бассейне'
# Updating name from '5.3 Негативное воздействие вод в результате разруш' to '5.3 Негативное воздействие вод в результате разрушения гидротехнических сооружений'
# Updating name from '5.4.1 Оценка негативного воздействия вод при перер' to '5.4.1 Оценка негативного воздействия вод при переработке берегов Цимлянского водохранилища'
# Updating name from '5.4.2 Оценка негативного воздействия вод при перер' to '5.4.2 Оценка негативного воздействия вод при переработке берегов р. Дон на участке от створа Цимлянского гидроузла до г. Аксай'
# Updating name from '5.4 Негативное воздействие вод при переработке бер' to '5.4 Негативное воздействие вод при переработке берегов водохранилищ и рек'
# Updating name from '5.5 Районирование территории бассейна по степени п' to '5.5 Районирование территории бассейна по степени паводковой опасности'
# Updating name from 'В Красногвардейском районе Белгородской области в ' to 'В Красногвардейском районе Белгородской области в результате эксплуатации коммунаровского и красногвардейского водозаборов сформировалась региональная депрессия уровней с интенсивностью до 0.25 м/год. Контуры сработки уровней в настоящее время прослеж...'
# Updating name from '7.1 Проблемы экологического состояния водных объек' to '7.1 Проблемы экологического состояния водных объектов'
# Updating name from '7.2.1. Исчерпание свободных водных ресурсов для до' to '7.2.1. Исчерпание свободных водных ресурсов для дополнительного использования (напряженный водохозяйственный баланс)'
# Updating name from '7.2.2 Обеспечение питьевого и хозяйственно-бытовог' to '7.2.2 Обеспечение питьевого и хозяйственно-бытового водоснабжения (проблемы водообеспечения питьевого и хозяйственно-бытового водоснабжения)'
# Updating name from '7.2 Проблемы водообеспечения' to '7.2 Проблемы водообеспечения'
# Updating name from '7.3.1 Ущербы вызванные затоплением хозяйственно ос' to '7.3.1 Ущербы вызванные затоплением хозяйственно освоенных территорий половодьями и паводками'
# Updating name from '7.3.2 Ущербы вызванные авариями на гидротехнически' to '7.3.2 Ущербы вызванные авариями на гидротехнических сооружениях'
# Updating name from '7.3.3 Ущербы вызванные переработкой берегов' to '7.3.3 Ущербы вызванные переработкой берегов'
# Updating name from '7.3 Проблемы негативного воздействия вод' to '7.3 Проблемы негативного воздействия вод'
# Updating name from '7.4.1 Развитие действующей системы мониторинга кач' to '7.4.1 Развитие действующей системы мониторинга качества поверхностных вод в бассейне р.Дон'
# Updating name from '7.4.2 Совершенствование организационного, норматив' to '7.4.2 Совершенствование организационного, нормативно-правового и экономического обеспечения процесса управления водными ресурсами и водопользования'
# Updating name from '7.4 Проблемы организационно-управленческого характ' to '7.4 Проблемы организационно-управленческого характера'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from '1.1 Современное состояние водохозяйственного компл' to '1.1 Современное состояние водохозяйственного комплекса бассейна'
# Updating name from '1.2 Характеристика решения ключевых проблем бассей' to '1.2 Характеристика решения ключевых проблем бассейна р.Дон по завершении выполнения мероприятий Схемы'
# Updating name from '1 Общая характеристика целевого состояния бассейна' to '1 Общая характеристика целевого состояния бассейна р.Дон по завершении выполнения мероприятий Схемы'
# Updating name from '2.1.1 Методический подход к установлению целевых п' to '2.1.1 Методический подход к установлению целевых показателей качества поверхностных вод (ЦПКВ)'
# Updating name from '2.1.2 Процедура установления ЦПКВ для расчетных во' to '2.1.2 Процедура установления ЦПКВ для расчетных водохозяйственных участков'
# Updating name from '2.1.3 Целевые показатели качества вод и привноса з' to '2.1.3 Целевые показатели качества вод и привноса загрязняющих веществ для водохозяйственных участков бассейна р.Дон'
# Updating name from '2.1.4 Целевые показатели по допустимому содержанию' to '2.1.4 Целевые показатели по допустимому содержанию и привносу микроорганизмов в водные объекты бассейна р.Дон'
# Updating name from '2.1.5 Целевые показатели допустимого содержания и ' to '2.1.5 Целевые показатели допустимого содержания и привноса радиоактивных веществ в водные объекты бассейна р.Дон'
# Updating name from '2.1.6 Целевые показатели качества подземных вод' to '2.1.6 Целевые показатели качества подземных вод'
# Updating name from '2.1 Целевые показатели качества воды в водных объе' to '2.1 Целевые показатели качества воды в водных объектах бассейна'
# Updating name from '2.2.1 Целевые показатели допустимого безвозвратног' to '2.2.1 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока по укрупненным водохозяйственным участкам бассейна р.Дон'
# Updating name from '2.2.2 Целевые показатели допустимого безвозвратног' to '2.2.2 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока и экологический сток по основным притокам бассейна р.Дон'
# Updating name from '2.2 Целевые показатели допустимого безвозвратного ' to '2.2 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока в бассейне'
# Updating name from '2 ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ВОДН' to '2 ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ ЭКОЛОГИЧЕСКОГО СОСТОЯНИЯ ВОДНЫХ  ОБЪЕКТОВ БАССЕЙНА р.ДОН'
# Updating name from '3.1 Современные и целевые показатели использования' to '3.1 Современные и целевые показатели использования водных ресурсов в бассейне'
# Updating name from '3.2 Целевые показатели допустимого использования в' to '3.2 Целевые показатели допустимого использования водных ресурсов в разрезе водохозяйственных участков'
# Updating name from '3.3 Целевые показатели допустимого использования в' to '3.3 Целевые показатели допустимого использования водных ресурсов по субъектам РФ в бассейне Дона'
# Updating name from '3 ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ ВОДООБЕСПЕЧЕНИЯ НАСЕЛЕНИЯ И О' to '3 ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ ВОДООБЕСПЕЧЕНИЯ НАСЕЛЕНИЯ И ОБЪЕКТОВ ЭКОНОМИКИ РЕЧНОГО БАССЕЙНА'
# Updating name from '4 ОСНОВНЫЕ ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ УМЕНЬШЕНИЯ НЕГАТИВНЫ' to '4 ОСНОВНЫЕ ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ УМЕНЬШЕНИЯ НЕГАТИВНЫХ ПОСЛЕДСТВИЙ НАВОДНЕНИЙ И ДРУГИХ ВИДОВ НЕГАТИВНОГО ВОЗДЕЙСТВИЯ ВОД'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from 'Целевые показатели' to '2.2 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока в бассейне'
# Updating name from 'Целевые показатели' to '2.2 Целевые показатели допустимого безвозвратного изъятия (забора) речного стока в бассейне'
# Updating name from 'Таблица 10.7 - Донской магистральный канал, млн.м3' to 'Таблица 10.7 - Донской магистральный канал, млн.м3'
# Updating name from 'Рисунок 11.1 - Режим работы Цимлянского водохранил' to 'Рисунок 11.1 - Режим работы Цимлянского водохранилища по вариантам 2020 г. А1,С1'
# Updating name from 'Рисунок 11.2 - Режим работы Цимлянского водохранил' to 'Рисунок 11.2 - Режим работы Цимлянского водохранилища по вариантам 2020 г. С2,А4'
# Updating name from 'Таблица 11.7 - Донской магистральный канал, млн.м3' to 'Таблица 11.7 - Донской магистральный канал, млн.м3'
# Updating name from 'Рисунок 12.10 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.10 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1947 года (вариант А4)'
# Updating name from 'Рисунок 12.11 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.11 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1948 года (вариант А4)'
# Updating name from 'Рисунок 12.12 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.12 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1951 года (вариант А4)'
# Updating name from 'Рисунок 12.13 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.13 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1953 года (вариант А4)'
# Updating name from 'Рисунок 12.14 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.14 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1955 года (вариант А4)'
# Updating name from 'Рисунок 12.15 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.15 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1963 года (вариант А4)'
# Updating name from 'Рисунок 12.17 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.17 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1981 года (вариант А4)'
# Updating name from 'Рисунок 12.18 - Расчетный режим Цимлянского водохр' to 'Рисунок 12.18 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1994 года (вариант А4)'
# Updating name from 'Рисунок 12.1 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.1 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1916 года (вариант А4)'
# Updating name from 'Рисунок 12.2 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.2 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1917 года (вариант А4)'
# Updating name from 'Рисунок 12.3 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.3 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1920 года (вариант А4)'
# Updating name from 'Рисунок 12.4 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.4 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1924 года (вариант А4)'
# Updating name from 'Рисунок 12.5 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.5 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1927 года (вариант А4)'
# Updating name from 'Рисунок 12.6 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.6 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1932 года (вариант А4)'
# Updating name from 'Рисунок 12.7 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.7 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1934 года (вариант А4)'
# Updating name from 'Рисунок 12.8 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.8 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1942 года (вариант А4)'
# Updating name from 'Рисунок 12.9 - Расчетный режим Цимлянского водохра' to 'Рисунок 12.9 - Расчетный режим Цимлянского водохранилища при пропуске половодья 1946 года (вариант А4)'
# Updating name from '' to 'Таблица 8.2 - Участок II: г.Задонск – г.Лиски, млн.м3'
# Updating name from 'Таблица 13.10 - Сводные показатели водохозяйственн' to 'Таблица 13.10 - Сводные показатели водохозяйственного баланса по участку 05.01.02.001 - р.Хопер от истока до впадения р.Ворона, млн.м3'
# Updating name from 'Таблица 13.11 - Сводные показатели водохозяйственн' to 'Таблица 13.11 - Сводные показатели водохозяйственного баланса по участку 05.01.02.002 - р.Ворона, млн.м3'
# Updating name from 'Таблица 13.12 - Сводные показатели водохозяйственн' to 'Таблица 13.12 - Сводные показатели водохозяйственного баланса по участку 05.01.02.003 - р.Савала, млн.м3'
# Updating name from 'Таблица 13.13 - Сводные показатели водохозяйственн' to 'Таблица 13.13 - Сводные показатели водохозяйственного баланса по участку 05.01.02.004 - р.Бузулук, млн.м3'
# Updating name from 'Таблица 13.14 - Сводные показатели водохозяйственн' to 'Таблица 13.14 - Сводные показатели водохозяйственного баланса по участку 05.01.02.005 - р.Хопер от впадения р.Ворона до устья без рр.Ворона, Савала, Бузулук, млн.м3'
# Updating name from 'Таблица 13.15 - Сводные показатели водохозяйственн' to 'Таблица 13.15 - Сводные показатели водохозяйственного баланса по участку 05.01.03.001 - р.Медведица, исток-выше впадения р.Терса, млн.м3'
# ...
# Updating name from '7.1.1.1 Гидроэнергетика' to '7.1.1.1 Гидроэнергетика'
# Updating name from '7.1.1.2 Тепловые станции' to '7.1.1.2 Тепловые станции'
# Updating name from '7.1.1 Характеристика использования водных ресурсов' to '7.1.1 Характеристика использования водных ресурсов для целей энергетики'
# Updating name from '7.1.2 Характеристика транспортного использования в' to '7.1.2 Характеристика транспортного использования водных объектов'
# Updating name from '7.1 Освоение поверхностных вод' to '7.1 Освоение поверхностных вод'
# Updating name from '7.2 Освоение подземных вод' to '7.2 Освоение подземных вод'
# Updating name from '7.3 Добыча полезных ископаемых' to '7.3 Добыча полезных ископаемых'
# Updating name from '7.4.1 Общие характеристики регулирующих емкостей и' to '7.4.1 Общие характеристики регулирующих емкостей и систем распределения речного стока'
# Updating name from '7.4.2 Оборотное и повторное водоснабжение' to '7.4.2 Оборотное и повторное водоснабжение'
# Updating name from '7.4.3 Мощности очистных сооружений' to '7.4.3 Мощности очистных сооружений'
# Updating name from '7.4 Информация о водохозяйственной инфраструктуре' to '7.4 Информация о водохозяйственной инфраструктуре'
# Updating name from '7 Характеристика хозяйственного освоения водных об' to '7 Характеристика хозяйственного освоения водных объектов и существующей водохозяйственной инфраструктуры'
# Updating name from '8.1 Использование поверхностных вод' to '8.1 Использование поверхностных вод'
# Updating name from '8.2 Использование подземных вод' to '8.2 Использование подземных вод'
# Updating name from '8.3 Характеристики систем водоотведения' to '8.3 Характеристики систем водоотведения'
# Updating name from '8.4 Рекреационное использование водных объектов' to '8.4 Рекреационное использование водных объектов'
# Updating name from '8.5 Использование водных объектов для рыболовства' to '8.5 Использование водных объектов для рыболовства'
# Updating name from '8.6 Характеристика особо охраняемых природных терр' to '8.6 Характеристика особо охраняемых природных территорий речного бассейна'
# Updating name from '8 Характеристика использования водных объектов' to '8 Характеристика использования водных объектов'
# Updating name from '9 Перечень водных объектов бассейна р. Урал и его ' to '9 Перечень водных объектов бассейна р. Урал и его частей, осуществление мер по охране которых возложено на органы государственной власти субъектов РФ'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from '1 Распределение водных объектов речного бассейна п' to '1 Распределение водных объектов речного бассейна по категориям'
# Updating name from '2.1 Оценка экологического состояния водных объекто' to '2.1 Оценка экологического состояния водных объектов по биологическим показателям'
# Updating name from '2.2 Оценка состояния водных объектов по гидрохимич' to '2.2 Оценка состояния водных объектов по гидрохимическим показателям'
# Updating name from '2 Оценка экологического состояния поверхностных во' to '2 Оценка экологического состояния поверхностных водных объектов речного бассейна'
# Updating name from '3.1 Качество подземных вод' to '3.1 Качество подземных вод'
# Updating name from '3.2 Загрязнение на водозаборах подземных вод' to '3.2 Загрязнение на водозаборах подземных вод'
# Updating name from '3.3 Участки загрязнения подземных вод' to '3.3 Участки загрязнения подземных вод'
# Updating name from '3 Оценка экологического состояния подземных водных' to '3 Оценка экологического состояния подземных водных объектов на территории речного бассейна'
# Updating name from '4.1 Селитебные территории' to '4.1 Селитебные территории'
# Updating name from '4.2 Промышленное освоение территории бассейна' to '4.2 Промышленное освоение территории бассейна'
# Updating name from '4.3 Сельскохозяйственное использование водосбора' to '4.3 Сельскохозяйственное использование водосбора'
# Updating name from '4.4 Техногенно нарушенные территории' to '4.4 Техногенно нарушенные территории'
# Updating name from '4.5 Рекреационное использование' to '4.5 Рекреационное использование'
# Updating name from '4 Оценка масштабов хозяйственного освоения речного' to '4 Оценка масштабов хозяйственного освоения речного бассейна'
# Updating name from '5.1 Водообеспечение поверхностными водами' to '5.1 Водообеспечение поверхностными водами'
# Updating name from '5.2 Водообеспечение подземными водами' to '5.2 Водообеспечение подземными водами'
# Updating name from '5.3.1 Природные факторы изменения водности в бассе' to '5.3.1 Природные факторы изменения водности в бассейне реки'
# Updating name from '5.3.2 Антропогенное воздействие' to '5.3.2 Антропогенное воздействие'
# Updating name from '5.3 Повышение социально-экономических и экологичес' to '5.3 Повышение социально-экономических и экологических рисков в связи с изменением гидрологических условий в бассейне реки Урал'
# Updating name from '5.4.1 Водообеспечение поверхностными водами' to '5.4.1 Водообеспечение поверхностными водами'
# Updating name from '5.4.2 Водообеспечение подземными водами' to '5.4.2 Водообеспечение подземными водами'
# Updating name from '5.4.3 Рост экономики и водообеспеченность' to '5.4.3 Рост экономики и водообеспеченность'
# Updating name from '5.4 Водный фактор в обеспечении экономической деят' to '5.4 Водный фактор в обеспечении экономической деятельности, социальных условий'
# Updating name from '5 Обеспеченность населения и экономики речного бас' to '5 Обеспеченность населения и экономики речного бассейна водными ресурсами'
# Updating name from '6.1 Затопление территорий' to '6.1 Затопление территорий'
# Updating name from '6.2.1 Распределение типов русел по длине основных ' to '6.2.1 Распределение типов русел по длине основных рек бассейна Урала'
# Updating name from '6.2.2 Гидролого-морфологический анализ русловых пр' to '6.2.2 Гидролого-морфологический анализ русловых процессов'
# Updating name from '6.2.3 Оценка антропогенной измененности русел рек ' to '6.2.3 Оценка антропогенной измененности русел рек бассейна Урала'
# Updating name from '6.2.4 Анализ карты «Антропогенная измененность рус' to '6.2.4 Анализ карты «Антропогенная измененность русел рек бассейна Урала»'
# Updating name from '6.2.5 Анализ карты «Опасные проявления русловых пр' to '6.2.5 Анализ карты «Опасные проявления русловых процессов на реках бассейна Урала»'
# Updating name from '6.2 Берегоразрушение' to '6.2 Берегоразрушение'
# Updating name from '6.3 Оценка устойчивости к антропогенным нагрузкам ' to '6.3 Оценка устойчивости к антропогенным нагрузкам русел рек бассейна Урала'
# Updating name from '6.4.1 Мероприятия, направленные на предотвращение ' to '6.4.1 Мероприятия, направленные на предотвращение негативных и опасных проявлений русловых процессов'
# Updating name from '6.4.2 Гидротехнические мероприятия по предотвращен' to '6.4.2 Гидротехнические мероприятия по предотвращению негативного воздействия вод'
# Updating name from '6.4.3 Снижение заиления русел рек' to '6.4.3 Снижение заиления русел рек'
# Updating name from '6.4.4 Пограничные аспекты русловых процессов' to '6.4.4 Пограничные аспекты русловых процессов'
# Updating name from '6.4 Предложения по учету русловых процессов при пр' to '6.4 Предложения по учету русловых процессов при проведении мероприятий по защите объектов производственной и социальной сферы'
# Updating name from '6 Оценка подверженности населения и хозяйственной ' to '6 Оценка подверженности населения и хозяйственной инфраструктуры речного бассейна негативному воздействию вод'
# Updating name from '7 Интегральная оценка экологического состояния реч' to '7 Интегральная оценка экологического состояния речного бассейна'
# Updating name from '8 Ключевые проблемы бассейна р. Урал' to '8 Ключевые проблемы бассейна р. Урал'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from '10 Финансово экономические и социально-экономическ' to '10 Финансово экономические и социально-экономические целевые показатели'
# Updating name from '1 Общая характеристика целевого состояния бассейна' to '1 Общая характеристика целевого состояния бассейна р. Урал'
# Updating name from '2 Характеристики целевого состояния отдельных водн' to '2 Характеристики целевого состояния отдельных водных объектов'
# Updating name from '3.1 Общие положения' to '3.1 Общие положения'
# Updating name from '3.2 Части бассейна р. Урал со сходными условиями ф' to '3.2 Части бассейна р. Урал со сходными условиями формирования качества воды'
# Updating name from '3.3 Долгосрочные целевые показатели качества воды' to '3.3 Долгосрочные целевые показатели качества воды'
# Updating name from '3.4 Значения ДЦП на замыкающих створах ВХУ' to '3.4 Значения ДЦП на замыкающих створах ВХУ'
# Updating name from '3 Целевые показатели качества воды в водных объект' to '3 Целевые показатели качества воды в водных объектах'
# Updating name from '4.1 Селитебные территории' to '4.1 Селитебные территории'
# Updating name from '4.2 Сельскохозяйственные угодья' to '4.2 Сельскохозяйственные угодья'
# Updating name from '4 Целевые показатели по сокращению поступления заг' to '4 Целевые показатели по сокращению поступления загрязняющих веществ с водосборной территории'
# Updating name from '5 Целевые показатели по уменьшению антропогенного ' to '5 Целевые показатели по уменьшению антропогенного влияния на изменение стоковых характеристик водных объектов, в т.ч. безвозвратных потерь'
# Updating name from '6.1 Целевые показатели уменьшения негативных после' to '6.1 Целевые показатели уменьшения негативных последствий наводнений'
# Updating name from '6.2.1 Целевые показатели снижения ущерба от берего' to '6.2.1 Целевые показатели снижения ущерба от берегоразрушения и заиления'
# Updating name from '6.2.2 Пограничные аспекты русловых процессов' to '6.2.2 Пограничные аспекты русловых процессов'
# Updating name from '6.2 Целевые показатели снижения ущерба от берегора' to '6.2 Целевые показатели снижения ущерба от берегоразрушения и заиления русел'
# Updating name from '6 Основные целевые показатели уменьшения негативны' to '6 Основные целевые показатели уменьшения негативных последствий воздействия вод'
# Updating name from '7 Целевые показатели развития системы государствен' to '7 Целевые показатели развития системы государственного мониторинга'
# Updating name from '8 Обеспечение населения качественной питьевой водо' to '8 Обеспечение населения качественной питьевой водой'
# Updating name from '9 Целевые показатели развития водохозяйственной ин' to '9 Целевые показатели развития водохозяйственной инфраструктуры речного бассейна'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'ЗАКЛЮЧЕНИЕ' to 'ЗАКЛЮЧЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from 'Целевые показатели' to '7 Целевые показатели развития системы государственного мониторинга'
# Updating name from 'Целевые показатели' to '7 Целевые показатели развития системы государственного мониторинга'
# Updating name from '1.1 Водохозяйственное районирование, расчетная лин' to '1.1 Водохозяйственное районирование, расчетная линейная водохозяйственная схема бассейна р.Урал'
# Updating name from '1.2 Методические положения расчета ВХБ бассейна р.' to '1.2 Методические положения расчета ВХБ бассейна р.Урал'
# Updating name from '1 расчет водохозяйственного баланса бассейна р. Ур' to '1 расчет водохозяйственного баланса бассейна р. Урал (ВХБ)'
# Updating name from '2.1 Водохозяйственный баланс бассейна р.Урал для г' to '2.1 Водохозяйственный баланс бассейна р.Урал для года 25% обеспеченности по стоку'
# Updating name from '2.2 Водохозяйственный баланс бассейна р.Урал для г' to '2.2 Водохозяйственный баланс бассейна р.Урал для года 50% обеспеченности по стоку'
# Updating name from '2.3 Водохозяйственный баланс бассейна р.Урал для г' to '2.3 Водохозяйственный баланс бассейна р.Урал для года 75% обеспеченности по стоку'
# Updating name from '2.4 Водохозяйственный баланс бассейна р.Урал для г' to '2.4 Водохозяйственный баланс бассейна р.Урал для года 95% обеспеченности по стоку'
# Updating name from '2 Водохозяйственный баланс бассейна р.Урал на совр' to '2 Водохозяйственный баланс бассейна р.Урал на современном уровне'
# Updating name from '3.1 Водохозяйственный баланс бассейна р.Урал для г' to '3.1 Водохозяйственный баланс бассейна р.Урал для года 25% обеспеченности по стоку'
# Updating name from '3.2 Водохозяйственный баланс бассейна р.Урал для г' to '3.2 Водохозяйственный баланс бассейна р.Урал для года 50% обеспеченности по стоку.'
# Updating name from '3.3 Водохозяйственный баланс бассейна р.Урал для г' to '3.3 Водохозяйственный баланс бассейна р.Урал для года 75% обеспеченности по стоку.'
# Updating name from '3.4 Водохозяйственный баланс бассейна р.Урал для г' to '3.4 Водохозяйственный баланс бассейна р.Урал для года 95% обеспеченности по стоку.'
# Updating name from '3 Водохозяйственный баланс бассейна р.Урал на уров' to '3 Водохозяйственный баланс бассейна р.Урал на уровне 2015 г.'
# Updating name from '4.1 Водохозяйственный баланс бассейна р.Урал для г' to '4.1 Водохозяйственный баланс бассейна р.Урал для года 25% обеспеченности по стоку'
# Updating name from '4.2 Водохозяйственный баланс бассейна р.Урал для г' to '4.2 Водохозяйственный баланс бассейна р.Урал для года 50% обеспеченности по стоку'
# Updating name from '4.3 Водохозяйственный баланс бассейна р.Урал для г' to '4.3 Водохозяйственный баланс бассейна р.Урал для года 75% обеспеченности по стоку'
# Updating name from '4.4 Водохозяйственный баланс бассейна р.Урал для г' to '4.4 Водохозяйственный баланс бассейна р.Урал для года 95% обеспеченности по стоку'
# Updating name from '4 Водохозяйственный баланс бассейна р.Урал на уров' to '4 Водохозяйственный баланс бассейна р.Урал на уровне 2020 г.'
# Updating name from '6 Баланс загрязняющих веществ' to '6 Баланс загрязняющих веществ'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from '1 Лимиты и квоты забора водных ресурсов из водных ' to '1 Лимиты и квоты забора водных ресурсов из водных объектов и сброса сточных вод по бассейну реки Урал'
# Updating name from 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ' to 'СПИСОК ИСПОЛЬЗОВАННЫХ ИСТОЧНИКОВ'
# Updating name from 'введение' to 'введение'
# Updating name from 'заключение' to 'заключение'
# Updating name from 'Перечень мероприятий по достижению целевого состояния речного бассейна' to '3 Перечень мероприятий по достижению целевого состояния речного бассейна'
# Updating name from '1.1 Фундаментальные мероприятия' to '1.1 Фундаментальные мероприятия'
# Updating name from '1.2 Институциональные мероприятия' to '1.2 Институциональные мероприятия'
# Updating name from '1.3 Мероприятия по улучшению оперативного управлен' to '1.3 Мероприятия по улучшению оперативного управления'
# Updating name from '1.4 Структурные мероприятия' to '1.4 Структурные мероприятия'
# Updating name from '1 Программа мероприятий СКИОВО' to '1 Программа мероприятий СКИОВО'
# Updating name from '2 Общая оценка вероятных воздействий реализации ме' to '2 Общая оценка вероятных воздействий реализации мероприятий Схемы на окружающую среду'
# Updating name from '3.1 Сводные показатели' to '3.1 Сводные показатели'
# Updating name from '3.2 Оренбургская область' to '3.2 Оренбургская область'
# Updating name from '3 Перечень мероприятий по достижению целевого сост' to '3 Перечень мероприятий по достижению целевого состояния речного бассейна'
# Updating name from 'ВВЕДЕНИЕ' to 'ВВЕДЕНИЕ'
# Updating name from 'Перечень мероприятий по достижению целевого состояния речного бассейна' to '3 Перечень мероприятий по достижению целевого состояния речного бассейна'
# Updating name from 'Перечень мероприятий по достижению целевого состояния речного бассейна' to '3 Перечень мероприятий по достижению целевого состояния речного бассейна'

# %% [markdown]
# ### Добавление текста для интерактивного исползования

# %%
# Тексты для каждого уровня структуры
texts = {
    1: [  # Уровень "Глава / Раздел"
        "Выберите всю интересующую Вас информацию из представленного списка разделов:",
        "Начните с раздела, который соответствует Вашему интересу:",
        "Ниже представлен список доступных разделов:",
        "Перейдите к разделу, который подходит Вашему запросу:",
        "Разделы помогут Вам быстро найти нужную информацию:",
        "Ознакомьтесь с предложенными разделами для поиска данных:",
        "Выберите подходящий раздел для более детального изучения:",
        "Исследуйте разделы, чтобы найти необходимую информацию:",
        "Список разделов создан для Вашего удобства. Начните выбор:",
        "Рассмотрите предложенные разделы и выберите наиболее подходящий:",
    ],
    2: [  # Уровень "Подраздел"
        "Выберите подраздел для уточнения информации:",
        "Подразделы содержат более узкоспециализированные данные:",
        "Для детализации информации выберите нужный подраздел:",
        "Подразделы помогут глубже изучить интересующую Вас тему:",
        "Выберите подраздел, чтобы продолжить работу с информацией:",
        "Список подразделов подготовлен для Вашего удобства:",
        "Доступные подразделы позволяют сузить область поиска:",
        "Выберите подраздел для конкретизации данных:",
        "Ознакомьтесь с подразделами для дальнейшего изучения:",
        "Список подразделов предложен ниже. Выберите подходящий:",
    ],
    3: [  # Уровень "Пункт"
        "Выберите пункт для более детального изучения:",
        "Каждый пункт предоставляет точную информацию по теме:",
        "Пункты содержат ключевые аспекты выбранного подраздела:",
        "Ознакомьтесь с пунктами для детального анализа:",
        "Выберите пункт, чтобы найти нужные данные:",
        "Доступные пункты представлены ниже для Вашего удобства:",
        "Выберите пункт, чтобы перейти к подробной информации:",
        "Список пунктов подготовлен для поиска нужных данных:",
        "Изучите пункты, чтобы получить полное представление о теме:",
        "Пункты позволят Вам уточнить интересующую информацию:",
    ],
    4: [  # Уровень "Подпункт"
        "Выберите подпункт для конкретизации данных:",
        "Каждый подпункт представляет узкую тему в рамках пункта:",
        "Подпункты содержат дополнительные сведения по теме:",
        "Перейдите к подпункту для более глубокого изучения:",
        "Список подпунктов поможет уточнить Ваш запрос:",
        "Выберите подходящий подпункт из приведённого списка:",
        "Подпункты позволяют найти дополнительные аспекты темы:",
        "Исследуйте подпункты для получения дополнительной информации:",
        "Выберите подпункт, чтобы перейти к следующим деталям:",
        "Список подпунктов приведён ниже. Выберите нужный:",
    ],
    5: [  # Уровень "Подподпункт"
        "Выберите подподпункт для окончательной детализации данных:",
        "Подподпункты содержат самую узкую специализацию по теме:",
        "Выберите подподпункт, чтобы завершить анализ информации:",
        "Список подподпунктов представлен для уточнения темы:",
        "Перейдите к подподпункту для завершения поиска данных:",
        "Подподпункты позволяют сосредоточиться на деталях темы:",
        "Выберите подподпункт из приведённого списка для анализа:",
        "Ознакомьтесь с подподпунктами для завершения изучения:",
        "Список подподпунктов поможет найти все нужные данные:",
        "Подподпункты представлены ниже для окончательного выбора:",
    ],
}

# %%
def add_texts_to_structure(node, level):
    if 'children' in node:
        if level in texts:
            text = random.choice(texts[level])
            # Вставляем текст после поля 'name'
            node_with_text = {'name': node['name'], 'text': text}
            if 'path' in node:
                node_with_text['path'] = node['path']
            node_with_text['children'] = node['children']
            node.clear()
            node.update(node_with_text)
        
        for child in node['children']:
            add_texts_to_structure(child, level + 1)

# Загрузка JSON файла
with open('hierarchical_structure.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Добавление текстов в структуру
for node in data:
    add_texts_to_structure(node, 1)

# Сохранение обновленного JSON файла
with open('hierarchical_structure.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

# %%
def sort_sections(data: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    """
    Recursively sort sections by the number in "Раздел X" in their names.
    """
    def extract_number(name: str) -> int:
        # Extract number from the section name "Раздел X"
        import re
        match = re.search(r"Раздел\s*(\d+)", name)
        if match:
            return int(match.group(1))
        return float('inf')  # For names without "Раздел X", place them last

    for item in data:
        if "children" in item:
            # Recursively sort the children
            item["children"] = sort_sections(item["children"])
    # Sort the current level
    data.sort(key=lambda x: extract_number(x.get("name", "")))
    return data

# Считывание JSON из файла
input_file = "hierarchical_structure.json"
output_file = "hierarchical_structure.json"

with open(input_file, "r", encoding="utf-8") as file:
    data = json.load(file)

# Сортировка
sorted_data = sort_sections(data)

# Сохранение результата в файл
with open(output_file, "w", encoding="utf-8") as file:
    json.dump(sorted_data, file, ensure_ascii=False, indent=4)

print(f"Сортированный JSON сохранен в {output_file}")
# Out:
# Сортированный JSON сохранен в hierarchical_structure.json
