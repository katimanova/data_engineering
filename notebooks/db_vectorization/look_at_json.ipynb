# %% [markdown]
# ### Взгляд на структуру json

# %%
import json
import pandas as pd
import re

# бибдиотеки для работы с текстом
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer
from langchain_core.documents import Document

# Укажите путь к вашему JSON-файлу
file_path = "../JSON/Печора/Исходные/Книга_4.json"

# Чтение JSON-файла
with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)

# %%
def extract_documents_recursive(sections, parent_title="", parent_level=0):
    """
    Рекурсивно извлекает документы из вложенных секций.
    :param sections: список секций.
    :param parent_title: заголовок родительской секции.
    :param parent_level: уровень родительской секции.
    :return: список объектов Document.
    """
    documents = []
    for section in sections:
        # Извлекаем текущую информацию
        title = section.get("title", "No Title")
        level = section.get("level", parent_level + 1)
        start_page = section.get("start_page", 0)
        end_page = section.get("end_page", 0)
        text = section.get("text", "")
        
        # Формируем метаданные
        metadata = {
            "title": title,
            "level": level,
            "parent_title": parent_title,
            "start_page": start_page,
            "end_page": end_page,
            'file': file_path.split('/')[-1]
        }
        
        # Создаём документ
        documents.append(Document(page_content=text, metadata=metadata))
        
        # Рекурсивно обрабатываем вложенные секции
        if "subsections" in section and isinstance(section["subsections"], list):
            documents.extend(
                extract_documents_recursive(
                    section["subsections"], parent_title=title, parent_level=level
                )
            )
    return documents

# Пример использования
documents = extract_documents_recursive(data)

# удаление только таблиц (на время)
def remove_table_and_save_titles(text):
    # Регулярное выражение для удаления содержимого таблиц, оставляя названия
    table_pattern = re.compile(
        r'((?:Таблица\s[\d.]+|Продолжение таблицы.*?)\s.*?)(?:\n.*?)+(?=(?:\n[А-Яа-я]|$))', 
        re.DOTALL
    )
    
    # Регулярное выражение для сохранения строк с рисунками (учитывает "рис.", "Рис.", "Рисунок")
    figure_pattern = re.compile(r'(?:рис\.|Рис\.|Рисунок)\s[\d.]+\s-.*?(?=\n|$)', re.IGNORECASE)
    
    # Удаляем содержимое таблиц, оставляя только их названия
    cleaned_text = table_pattern.sub(r'\1', text)
    
    # Убеждаемся, что строки с рисунками остаются неизменными
    figures = figure_pattern.findall(text)
    for figure in figures:
        if figure not in cleaned_text:
            cleaned_text += f"\n{figure}\n"

    return cleaned_text

for doc in documents:
    text = doc.page_content
    result = remove_table_and_save_titles(text)
    doc.page_content = result
    
# Формируем таблицу метаданных
metadata_table = pd.DataFrame([doc.metadata for doc in documents])
metadata_table.head(10)
# Out:
#                                                title  level  \
# 0                                           ВВЕДЕНИЕ      1
# 1                       1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ      1
# 2   1.1. Методика расчета водохозяйственных балансов      2
# 3  1.2. Водохозяйственное районирование бассейна ...      2
# 4           1.3. Водные ресурсы бассейна реки Печоры      2
# 5  1.4. Расчеты водохозяйственных балансов для ле...      2
# 6                                        1.5. Выводы      2
# 7    2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ      1
# 8                   2.1 Методика расчета балансов ЗВ      2
# 9                             2.2 Расчет балансов ЗВ      2
#
#                                       parent_title  start_page  end_page  \
# 0                                                            8         8
# 1                                                            8        16
# 2                     1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ           8        11
# 3                     1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ          12        14
# 4                     1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ          15        15
# 5                     1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ          16        16
# 6                     1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ          17        17
# 7                                                           17        29
# 8  2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ          19        20
# 9  2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ          21        23
#
#            file
# 0  Книга_4.json
# 1  Книга_4.json
# 2  Книга_4.json
# 3  Книга_4.json
# 4  Книга_4.json
# 5  Книга_4.json
# 6  Книга_4.json
# 7  Книга_4.json
# 8  Книга_4.json
# 9  Книга_4.json

# %% [markdown]
# ## Предобработка текста: стоит ли это делать?
#
# ### Самый главный вопрос: нужно ли это вообще?
#
# Подход к предобработке текста зависит от используемого метода обработки данных:
#
# 1. **Методы типа TF-IDF или CountVectorizer:**
#    - В таких случаях приведение текста к максимально простой форме (лемматизация, токенизация, удаление стоп-слов) действительно оправдано. Это улучшает качество признаков, сокращает размерность матрицы и помогает получить более точные результаты. Упрощенный текст позволяет фокусироваться на важной информации, исключая "шум".
#
# 2. **Модели типа BERT, FastText:**
#    - Здесь ситуация иная. Эти модели обучены на текстах в их естественной форме и учитывают контекст, порядок слов и грамматические структуры. Приведение текста к упрощенной форме может ухудшить качество эмбеддингов, так как теряется информация, важная для понимания модели. Вместо этого стоит сосредоточиться на чистоте текста:
#      - Удалить лишние символы (`\n`, табуляции, спецсимволы).
#      - Привести регистр текста к единообразию (например, в нижний регистр, если это нужно).
#      - Сохранить стоп-слова и структуру текста.
#
# Итак, выбор подхода зависит от используемого метода обработки текста и ваших целей.
# Наша идея использовать модели типа `BERT`, поэтому обработка будет соответсвующей

# %%
# Функция для предобработки текста
def preprocess_page_content(text):
    # Удаляем лишние пробелы и символы табуляции
    text = re.sub(r"\s+", " ", text)
    # Приводим слова, написанные полностью в верхнем регистре, к заглавной первой букве
    text = re.sub(r"\b([А-ЯЁ]{2,})\b", lambda m: m.group(1).capitalize(), text)
    # Убираем спецсимволы, оставляя только буквы, цифры, пробелы и базовую пунктуацию
    text = re.sub(r"[^\w\s.,!?-–—()\"']", " ", text)
    # Очищаем лишние пробелы после всех операций
    return text.strip()

# Обрабатываем page_content для всех документов
for doc in documents:
    doc.page_content = preprocess_page_content(doc.page_content)

documents
# Out:
# [Document(metadata={'title': 'ВВЕДЕНИЕ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 8, 'file': 'Книга_4.json'}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8'),
#  Document(metadata={'title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 16, 'file': 'Книга_4.json'}, page_content=''),
#  Document(metadata={'title': '1.1. Методика расчета водохозяйственных балансов', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 8, 'end_page': 11, 'file': 'Книга_4.json'}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8 Таблица 1.1 Составляющие расчета баланса (приходной, расходной и балансовой частей)'),
#  Document(metadata={'title': '1.2. Водохозяйственное районирование бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 12, 'end_page': 14, 'file': 'Книга_4.json'}, page_content='1.2. Водохозяйственное районирование бассейна реки Печоры Водохозяйственное районирование бассейна дано на рис.1. В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй  ственных участков, назначенных на реках бассейна (табл.1), характеристики ство  ров, замыкающих водохозяйственные участки (табл.2). Таблица 1 к рис.1'),
#  Document(metadata={'title': '1.3. Водные ресурсы бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 15, 'end_page': 15, 'file': 'Книга_4.json'}, page_content='Таблица 2 к рис.1'),
#  Document(metadata={'title': '1.4. Расчеты водохозяйственных балансов для лет различной водности', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 16, 'end_page': 16, 'file': 'Книга_4.json'}, page_content='Книге 4 (Прилож.6 к Скиово), приложение 1 табл.1 и приложение 2 табл.1 соответственно. 1.4. Расчеты водохозяйственных балансов для лет различной водности Расчёты водохозяйственных балансов по расчетным водохозяйственным участкам бассейна, подбассейнам и бассейну в целом выполнены на расчетные уровни 2008г. (современный уровень), 2015г., 2020г. и 2025г. (перспектива). В качестве современного расчетного уровня принят 2008г., поскольку за предыдущие 3 года водопользование в бассейне по данным 2 Тп водхоз характе  ризовалось наибольшими величинами в 2008 году. Расчёты выполнялись для характерных по водности лет – среднему (50  обеспеченности), маловодному (75 обесп.) и исключительно маловодному (95 обесп.). В качестве расчетных периодов приняты    Водохозяйственный год  с мая по апрель,   Нелимитирующий период (весна) – с мая по июль,   Лимитирующие  период – с августа по апрель, сезон (зима) – с декабря по апрель, месяцы  зимний – март, летне осенний – ноябрь. В расчете водохозяйственных балансов использовались следующие исход  ные данные  – поверхностные водные ресурсы в створах, замыкающих водохозяйственные и расчётные в х участки (приведены в Пояснительной записке к Книге 4 (При  лож.6 к Скиово), таблицы 1 приложений 1 и 2)  – объемы водопотребления и водоотведения на современный уровень 2008г. (базовый), полученные на основании данных статотчетности 2 Тп водхоз, предоставленных Двинско Печорским Бассейновым водным управлением (Бву) (приведены в Пояснительной записке к Книге 4, таблицы 2 приложений 1 и 2)  – водопользование на перспективу 2015г., 2020г. и 2025г. (приведено в Поясни  тельной записке к Книге 4 (Прилож.6 к Скиово), таблицы 3 5 приложения 1)  – экологический сток, определен  – для нелимитирующего периода  в зависимости от водности года как процент от объема естественного поверхностного стока в створе, замы  кающем расчетный водохозяйственный участок – для года 50  обеспе  ченности – 80  , 75  обесп.– 85  и год 95  обесп. – 90  от естествен  ного объема стока  – для лимитирующего периода  лето осень – 75  от стока минимального летнего месяца и зима – 75  от стока минимального зимнего месяца (в 16'),
#  Document(metadata={'title': '1.5. Выводы', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 17, 'end_page': 17, 'file': 'Книга_4.json'}, page_content='отдельных случаях выполнена корректировка экологического стока исхо  дя из конкретных условий водопользования), млн.м3. Величины экологического стока приведены в Пояснительной записке к Книге 4 (Прилож.6 к Скиово), таблице 6 приложения 1 и таблицах 5 7 приложения 2. Расчеты водохозяйственных балансов для лет различной водности в современных условиях и на перспективу развития экономики представлены в при  ложении 1 табл.1  36    по водохозяйственным участкам (табл. 1 12)    по подбассейну (табл. 13 – 24)   по бассейну (табл. 25 – 36). 1.5. Выводы 1) Приведенный метод расчета балансов позволяет оценить использование водных ресурсов, выявить участки с излишками или дефицитом водных ресурсов и при необходимости разработать мероприятия для покрытия дефицитов. 2) Бассейн р.Печоры полностью водообеспечен по объему поверхност  ных и подземных водных ресурсов  дефицитов воды не выявлено ни по одному водохозяйственному или расчетному участку с учетом обеспечения расходов воды в водных объектах, требуемых для покрытия экологического стока и стока, обеспечивающего условия судоходства. 3) Расчет в х балансов на перспективу 2015, 2020 и 2025гг. показал, что уве  личение забора водных ресурсов в рамках установленных на перспективу лими  тов не приводит к возникновению дефицитов водных ресурсов (т.е. результаты балансов могут считаться обоснованием установленных в Схеме лимитов забора (изъятия) водных ресурсов). С учетом увеличевшегося забора воды остаются из  лишки водных ресурсов, в пределах которых может быть при необходимости уве  личено водопотребление сверх установленных на эти периоды лимитов. 4) Разработка дополнительных мероприятий по водообеспечению населе  ния и объектов экономики водными ресурсами в части объемов воды не требует  ся. 2. Балансы Загрязняющих Веществ В Поверхностных Водных Объектах Бассейна Балансы загрязняющих веществ (Зв) в поверхностных водных объектах бассейна (далее балансы Зв) позволяют оценить количество привноса Зв в вод  ные объекты бассейна от точечных и диффузных источников загрязнения как с со  средоточенными, так и с рассредоточенными сточными водами. При расчёте ба  лансов учитывается также и поступление Зв с территорий без антропогенной нагрузки (естественное фоновое загрязнение водных объектов). Расчеты балансов Зв приведены в приложении 2. 17'),
#  Document(metadata={'title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'level': 1, 'parent_title': '', 'start_page': 17, 'end_page': 29, 'file': 'Книга_4.json'}, page_content=''),
#  Document(metadata={'title': '2.1 Методика расчета балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 19, 'end_page': 20, 'file': 'Книга_4.json'}, page_content='2.1 Методика расчета балансов Зв Расчеты балансов Зв выполнены по формуле (2)  Мв   Мф   Мс   Мд – Ми   Мн тонн год, (2) где  Мв – поступление Зв с вышерасположенного расчетного участка  Мф – поступление Зв с территории, где отсутствует антропогенная нагруз  ка  Мс – поступление Зв от точечных источников загрязнения  Мд – поступление Зв с территории диффузных источников загрязнения  Ми – изъятие Зв с забором воды. Мн – поступление Зв на нижерасположенный расчетный участок. Мд   Мду   Мдн, тонн год, (3) где  Мду – поступление Зв с территорий диффузных потенциально управля  емых источников загрязнения  Мдн – поступление Зв с территории диффузных неуправляемых источников загрязнения. Мду   Мдпп   Мдсх   Мдгп, тонн год, (4) где  Мдпп – поступление Зв с неканализованной территорий промышленных предприятий и зон их опасного влияния  Мдсх – поступление Зв с территории сельхозпредприятий (животноводче  ские комплексы, фермы, птицефабрики и т.п.)  Мдгп – поступление Зв с неканализованных территорий городских поселе  ний (города и пгт). Мдн   Мдсп   Мдсу   Мдоп   Мдад   Мджд   Мдпо   Мднп   Мдзу, тонн год, (5) где  Мдсп – поступление Зв с территории сельских поселений  Мдсу – поступление Зв с территории сельхозугодий  Мдоп – поступление Зв с территории оленьих пастбищ  Мдад – поступление Зв с территории автодорог  Мджд – поступление Зв с территории железных дорог  Мдпо – поступление Зв с территории свалок Тбо и промотходов  Мднп – поступление Зв с территории нефте  и газопроводов  Мдзу   поступление Зв с территории зон умеренного влияния промышлен  ных предприятий. 19 В формулу расчета баланса включены значения поступления Зв только от тех источников загрязнения водных объектов, которые имеются в пределах рассматриваемого бассейна. Связь между составляющими баланса и обозначениями переменных в формулах представлена в табл. 2.1. Таблица 2.1   строки ба'),
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json'}, page_content='Объём ливневых, талых и фильтрационных сточных вод рассчитан как произведение слоя стока на площадь территории источника загрязнения  Wi   h х Fi х10 3 (7) где  h   слой стока с территории источника загрязнения, принятый по слою стока на расчетном водохозяйственном участке, мм год  Fi   площадь территории i ого источника загрязнения, км2 Значения концентрации Зв в воде, поступающей в водный объект от диффузных источников загрязнения (Cij), получены по материалам исследований различных научных и проектных организаций, литературным источникам, приняты по данным действующих нормативно методических документов, а по некоторым веществам – на основании экспертной оценки. Обоснование принятых значений концентраций Зв в рассредоточенных ливневых и талых сточных водах и объемов сточных вод, а также расчеты по  ступления Зв от различных источников загрязнения на расчетный период 2009г. (существующее положение) приведены в Пояснительной записке к Книге 4 (При  ложение 6 к Схеме) в прил.3 табл.8 и 29. Полученные величины поступления Зв использованы в расчетах балансов Зв на расчетный уровень 2009г. для водности года 50  и 95  обеспеченности. 2.2 Расчет балансов Зв Балансы Зв на современный уровень выполнены на основе фактических данных 2 Тп водхоз за 2009г. о поступлении Зв в водные объекты с сосредото  ченными сточными водами и расчетных величин поступления Зв от диффузных источников загрязнения. В балансе учтены все источники загрязнения (точечные, диффузные управляемые и неуправляемые), а также поступление Зв с террито  рий без антропогенной нагрузки. Балансы Зв на перспективу развития экономики 2020г и 2025г. выполне  ны с учетом параметров развития Республики Коми и Нао, содержащихся в стратегиях развития субъектов Рф, а также в «Стратегии развития Северо Запад  ного федерального округа на период до 2020г.». Расчеты балансов Зв на перспективу выполнены на основе расчета ба  лансов Зв на современный расчетный уровень 2009г., к позициям которого приме  нялись коэффициенты, учитывающие рост промышленного производства к 2020г. и 2025г. по отношению к современному уровню. Для управляемых источников загрязнения – точечных (сосредоточенные сточные воды) и диффузных потенциально управляемых – учитывалось снижение поступления Зв в водные объекты в соответствии с «Концепцией долгосрочного социально экономического развития Рф на период до 2020г.», утвержденной рас  поряжением Правительства Рф от 17.11.2008г., для реализации которой разра  21 ботана «Водная стратегия Рф», утвержденная распоряжением Правительства Рф от 27.08.2009г.   1235 р. Коэффициент снижения рассчитан исходя из уменьше  ния к 2020г. значения показателя «Объем организованного сброса загрязняющих веществ в поверхностные водные объекты» до 6.6 млн.тонн по отношению к 2007г. – 11 млн.тонн год (11   6,6   1,7). Для точечных и потенциально управля  емых диффузных источников загрязнения коэффициент поступления Зв в 2020г. по отношению к 2009г. принят равным 1,35 (уменьшение понижающего коэффи  циента в 2 раза обусловлено тем, что к 2015г. практически никаких мероприятий по снижению поступления Зв в водные объекты водопользователями выполнено не было), к 2025г. – 1,7. Обоснование и расчеты коэффициентов, использованных для перехода от современного расчетного уровня (2009г.) на расчетные уровни 2020г. и 2025г., приведены в приложении 2а. Основной вариант расчета балансов Зв на 2020 и 2025гг. выполнен ис  ходя из  – «Стратегии социально экономического развития Республики Коми на пе  риод до 2020 года» с изменениями от 12.02.2014г., согласно которой объем промышленного производства в республике в 2020 году к уровню 2011 года увели  чится в 1,3 раза  – проекта «Стратегии социально экономического развития Ненецкого автономного округа на период до 2030г»., по которой к 2030 году рост про ...
#  Document(metadata={'title': '2.3. Анализ результатов расчетов балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 24, 'end_page': 28, 'file': 'Книга_4.json'}, page_content='При благоприятных внешних и внутренних условиях прирост производства продукции сельского хозяйства в 2020 году к уровню 2011 года составит 13,6 процента. Производство скота и птицы (в живом весе) к 2020 году возрастет к уровню 2011 года на 26,7 процента, молока   на 12,5 процента. Динамичное развитие получит рыболовство и рыбоводство. Реализация ме  роприятий позволит сохранить уровень и доступность для населения ценных ви  дов рыб в районах традиционного рыболовства. Производство товарной рыбы увеличится к 2020 году относительно 2011 года в 1,4 раза. Согласно Проекта «Стратегии социально экономического развития Ненец  кого автономного округа до 2030г» объем промышленного производства округа к 2025 г. увеличится по сравнению с 2007г. в 2,48 раза. Исходя из сценария разви  тия региона на долгосрочный период, предполагается стабильный ежегодный экономический рост в 4 6 процентов по отношению к предыдущему году. Дополнительные варианты расчета балансов Зв на 2020г. для разных уровней перспективного развития экономики выполнен исходя из параметров развития экономики, заложенных в «Стратегии развития Северо Западного фе  дерального округа на период до 2020г.». В Стратегии рассмотрены три варианта перспективного развития – песси  мистический, оптимистический и базовый. При этом параметры базового варианта развития экономики региона близки к параметрам оптимистического варианта. В выполненных расчетах балансов Зв для республики Коми и Нао приме  няется единый коэффициент, соответствующий варианту развития Сзфо. Выкопировка из «Стратегии социально экономического развития Северо Западно  го федерального округа на период до 2020г.» и расчет коэффициентов для песси  мистического, оптимистического и базового вариантов развития экономики регио  на приведены в приложении 2а. Расчет вариантов расчета балансов Зв на разные уровни перспективного развития экономики региона приведены в Прил. к Пз, прил.6 табл.1 12. 2.3. Анализ результатов расчетов балансов Зв Балансы Зв рассчитаны по 20 расчетным, 6 водохозяйственным участ  кам, подбассейнам и бассейну в целом. Расчет выполнен для среднего по водно  сти (50  обесп.) и очень маловодного (95  обесп.) года. Расчетный уровень хо  зяйственного освоения бассейна – современный (2009г.) и перспектива (2020г., 2025г.). Расчет выполнен на основе действующих методических и нормативных документов согласно методике, изложенной в п.2.1. В расчете не учитывались эффекты бионакопления, осаждения Зв, транс  формации их и т.п. ввиду отсутствия соответствующих методик и пособий. По 24 этой же причине также не учитывалось поступление Зв от вторичных источников загрязнения (донные отложения). Однако, несмотря на эти обстоятельства, ба  лансы Зв достоверно отражают основные источники загрязнения и степень ан  тропогенной нагрузки на водные объекты. Анализ результатов балансов Зв выполнен по варианту расчета со следу  ющими условиями  расчет для 6 ти водохозяйственных участков для очень ма  ловодного года (95  обесп.), расчетный уровень – существующее положение 2009г. Оценка вклада отдельных источников загрязнения в суммарное поступле  ние Зв в водные объекты от всех источников (в год 95  обеспеченности) дана в таблице 2.2. Таблица 2.2 Оценка вклада отдельных источников загрязнения в суммарное поступление Зв'),
#  Document(metadata={'title': '2.4 Выводы', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 29, 'end_page': 29, 'file': 'Книга_4.json'}, page_content='2.4 Выводы 1) Основной объем стока с территории бассейна в водные объекты при  ходится на поверхностный дождевой и талый сток с незагрязненных территорий (92  от суммарного объема стока на участке). Поступление веществ двойного ге  незиса в водные объекты также более чем на 90  обусловлено поступлением их с незагрязненных территорий за счет природного содержания в воде. 2) Основной вклад в суммарное поступление Зв в водные объекты – от 78 до 90  приходится на диффузные управляемые источники загрязнения, при этом от 76 до 90  приходится на долю территорий промышленных предприятий и зон их влияния. 3) Сосредоточенные источники загрязнения водных объектов – водовыпус  ки предприятий – вносят до 1,5  от суммарного поступления Зв на в х участке, при этом локально они могут оказывать значительное негативное воздействие на водные объекты вследствие содержания в сточных водах загрязняющих веществ в концентрациях, превышающих допустимые значения. 4) Исходя из вклада различных источников в суммарное загрязнение вод, существенного снижения поступления загрязняющих веществ в водные объекты можно добиться, реализуя в первую очередь мероприятия по снижению поступле  ния Зв от диффузных источников  – перехват загрязненного стока с территорий диффузных потенциально управляемых источников загрязнения (строительство ливневой канализации или перехват стока сетью канав на наиболее загрязненных участках территорий) с очисткой стока перед поступлением его в водные объекты  – ликвидация источников загрязнения на территориях, прилегающих к вод  ным объектам, путем их выноса за пределы водоохранных зон (Воз) и прибреж  ных защитных полос (Пзп) водных объектов  – установление и организация на местности Воз и Пзп водных объектов. Указанные мероприятия содержатся в программе мероприятий в Книге 6 Схемы в составе мероприятий по охране водных объектов от загрязнения, засоре  ния и заиления (группа мероприятий по улучшению оперативного управления за использованием и охраной водных объектов). 5) Таким образом, результаты балансов Зв служат обоснованием необхо  димости разработки мероприятий по снижению поступления Зв от конкретных ис  точников загрязнения, позволяют установить очередность выполнения мероприя  тий с целью достижения максимальной их эффективности и улучшения состояния экосистем и водных объектов в кратчайшие сроки. 29'),
#  Document(metadata={'title': 'Приложение 1', 'level': 1, 'parent_title': '', 'start_page': 30, 'end_page': 273, 'file': 'Книга_4.json'}, page_content='Приложение 1 Водохозяйственные балансы по водохозяйственным участкам бассейна р.Печоры для лет различной водности на расчетные уровни 2008 (современный уровень), 2015, 2020, 2025гг. (перспективный уровень). Таблицы 1   36 30 Таблица 1 Водохозяйственные балансы по водохозяйственным участкам бассейна реки Печоры')]

# %% [markdown]
# ### Разбиение до фрагментов 1024 токена (под конкретную модель)

# %%
# часть кода для того чтобы понимать объем докуметов в токенах

# Загрузка токенизатора
model_name = "deepvk/USER-bge-m3"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Функция для подсчета числа токенов
def get_max_token_document(documents):
    """
    Находит документ с наибольшим количеством токенов.
    :param documents: список объектов Document
    :return: документ с наибольшим числом токенов и длина этого текста в токенах
    """
    max_tokens = 0
    max_doc = None

    for doc in documents:
        # Токенизация текста документа
        tokens = tokenizer(doc.page_content, add_special_tokens=False)["input_ids"]
        num_tokens = len(tokens)
        print(f"Document: {doc.metadata.get('title', 'No Title')} has {num_tokens} tokens.")
        
        # Проверяем, больше ли текущий текст максимума
        if num_tokens > max_tokens:
            max_tokens = num_tokens
            max_doc = doc

    return max_doc, max_tokens

# Пример использования
max_doc, max_tokens = get_max_token_document(documents)
print(f"The document with the most tokens is: {max_doc.metadata.get('title', 'No Title')}, with {max_tokens} tokens.")
# максимальная длина токенов, обрабатываемых моделью
model = SentenceTransformer("deepvk/USER-bge-m3")
print("Max sequence length:", model.max_seq_length)
# Out:
# Document: ВВЕДЕНИЕ has 413 tokens.
# Document: 1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ has 0 tokens.
# Document: 1.1. Методика расчета водохозяйственных балансов has 435 tokens.
# Document: 1.2. Водохозяйственное районирование бассейна реки Печоры has 99 tokens.
# Document: 1.3. Водные ресурсы бассейна реки Печоры has 6 tokens.
# Document: 1.4. Расчеты водохозяйственных балансов для лет различной водности has 614 tokens.
# Document: 1.5. Выводы has 575 tokens.
# Document: 2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ has 0 tokens.
# Document: 2.1 Методика расчета балансов ЗВ has 508 tokens.
# Document: 2.2 Расчет балансов ЗВ has 1884 tokens.
# Document: 2.3. Анализ результатов расчетов балансов ЗВ has 755 tokens.
# Document: 2.4 Выводы has 538 tokens.
# Document: Приложение 1 has 90 tokens.
# The document with the most tokens is: 2.2 Расчет балансов ЗВ, with 1884 tokens.
# Max sequence length: 8192

# %%
# Загрузка модели и токенизатора
model_name = "deepvk/USER-bge-m3"
model = SentenceTransformer(model_name)
tokenizer = model.tokenizer

# Функция для разбивки текста на части с перекрытием
def split_text_with_overlap(text, max_tokens, overlap=100):
    """
    Разбивает текст на части, не превышающие max_tokens токенов, с перекрытием.
    Возвращает список частей.
    """
    tokens = tokenizer(text, add_special_tokens=False)["input_ids"]
    num_tokens = len(tokens)
    
    # Если текст уже меньше лимита, возвращаем как есть
    if num_tokens <= max_tokens:
        return [text]
    
    # Разбиваем текст с перекрытием
    chunks = []
    start = 0
    while start < num_tokens:
        end = min(start + max_tokens, num_tokens)
        chunk_tokens = tokens[start:end]
        chunk_text = tokenizer.decode(chunk_tokens, skip_special_tokens=True)
        chunks.append(chunk_text)
        
        # Сдвигаем начало с учетом перекрытия
        start += max_tokens - overlap
    
    return chunks

# Функция для обработки списка документов
def process_documents_with_overlap(documents, max_tokens=1024, overlap=100):
    """
    Обрабатывает список документов. Если текст документа превышает max_tokens,
    разбивает его на части с перекрытием и создает новые документы с теми же метаданными.
    """
    processed_documents = []
    
    for doc in documents:
        # Получаем текст и токенизируем его
        text = doc.page_content
        metadata = doc.metadata
        
        # Разбиваем текст на части с перекрытием
        chunks = split_text_with_overlap(text, max_tokens, overlap)
        
        # Создаем новые документы для каждой части
        for idx, chunk in enumerate(chunks):
            new_metadata = metadata.copy()
            new_metadata["chunk_index"] = idx + 1  # Добавляем индекс части
            new_metadata["total_chunks"] = len(chunks)
            processed_documents.append(Document(metadata=new_metadata, page_content=chunk))
    
    return processed_documents

# Обработка документов с перекрытием
processed_documents = process_documents_with_overlap(documents)
processed_documents
# Out:
# [Document(metadata={'title': 'ВВЕДЕНИЕ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 8, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8'),
#  Document(metadata={'title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 16, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content=''),
#  Document(metadata={'title': '1.1. Методика расчета водохозяйственных балансов', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 8, 'end_page': 11, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8 Таблица 1.1 Составляющие расчета баланса (приходной, расходной и балансовой частей)'),
#  Document(metadata={'title': '1.2. Водохозяйственное районирование бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 12, 'end_page': 14, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='1.2. Водохозяйственное районирование бассейна реки Печоры Водохозяйственное районирование бассейна дано на рис.1. В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй  ственных участков, назначенных на реках бассейна (табл.1), характеристики ство  ров, замыкающих водохозяйственные участки (табл.2). Таблица 1 к рис.1'),
#  Document(metadata={'title': '1.3. Водные ресурсы бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 15, 'end_page': 15, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='Таблица 2 к рис.1'),
#  Document(metadata={'title': '1.4. Расчеты водохозяйственных балансов для лет различной водности', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 16, 'end_page': 16, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='Книге 4 (Прилож.6 к Скиово), приложение 1 табл.1 и приложение 2 табл.1 соответственно. 1.4. Расчеты водохозяйственных балансов для лет различной водности Расчёты водохозяйственных балансов по расчетным водохозяйственным участкам бассейна, подбассейнам и бассейну в целом выполнены на расчетные уровни 2008г. (современный уровень), 2015г., 2020г. и 2025г. (перспектива). В качестве современного расчетного уровня принят 2008г., поскольку за предыдущие 3 года водопользование в бассейне по данным 2 Тп водхоз характе  ризовалось наибольшими величинами в 2008 году. Расчёты выполнялись для характерных по водности лет – среднему (50  обеспеченности), маловодному (75 обесп.) и исключительно маловодному (95 обесп.). В качестве расчетных периодов приняты    Водохозяйственный год  с мая по апрель,   Нелимитирующий период (весна) – с мая по июль,   Лимитирующие  период – с августа по апрель, сезон (зима) – с декабря по апрель, месяцы  зимний – март, летне осенний – ноябрь. В расчете водохозяйственных балансов использовались следующие исход  ные данные  – поверхностные водные ресурсы в створах, замыкающих водохозяйственные и расчётные в х участки (приведены в Пояснительной записке к Книге 4 (При  лож.6 к Скиово), таблицы 1 приложений 1 и 2)  – объемы водопотребления и водоотведения на современный уровень 2008г. (базовый), полученные на основании данных статотчетности 2 Тп водхоз, предоставленных Двинско Печорским Бассейновым водным управлением (Бву) (приведены в Пояснительной записке к Книге 4, таблицы 2 приложений 1 и 2)  – водопользование на перспективу 2015г., 2020г. и 2025г. (приведено в Поясни  тельной записке к Книге 4 (Прилож.6 к Скиово), таблицы 3 5 приложения 1)  – экологический сток, определен  – для нелимитирующего периода  в зависимости от водности года как процент от объема естественного поверхностного стока в створе, замы  кающем расчетный водохозяйственный участок – для года 50  обеспе  ченности – 80  , 75  обесп.– 85  и год 95  обесп. – 90  от естествен  ного объема стока  – для лимитирующего периода  лето осень – 75  от стока минимального летнего месяца и зима – 75  от стока минимального зимнего месяца (в 16'),
#  Document(metadata={'title': '1.5. Выводы', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 17, 'end_page': 17, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='отдельных случаях выполнена корректировка экологического стока исхо  дя из конкретных условий водопользования), млн.м3. Величины экологического стока приведены в Пояснительной записке к Книге 4 (Прилож.6 к Скиово), таблице 6 приложения 1 и таблицах 5 7 приложения 2. Расчеты водохозяйственных балансов для лет различной водности в современных условиях и на перспективу развития экономики представлены в при  ложении 1 табл.1  36    по водохозяйственным участкам (табл. 1 12)    по подбассейну (табл. 13 – 24)   по бассейну (табл. 25 – 36). 1.5. Выводы 1) Приведенный метод расчета балансов позволяет оценить использование водных ресурсов, выявить участки с излишками или дефицитом водных ресурсов и при необходимости разработать мероприятия для покрытия дефицитов. 2) Бассейн р.Печоры полностью водообеспечен по объему поверхност  ных и подземных водных ресурсов  дефицитов воды не выявлено ни по одному водохозяйственному или расчетному участку с учетом обеспечения расходов воды в водных объектах, требуемых для покрытия экологического стока и стока, обеспечивающего условия судоходства. 3) Расчет в х балансов на перспективу 2015, 2020 и 2025гг. показал, что уве  личение забора водных ресурсов в рамках установленных на перспективу лими  тов не приводит к возникновению дефицитов водных ресурсов (т.е. результаты балансов могут считаться обоснованием установленных в Схеме лимитов забора (изъятия) водных ресурсов). С учетом увеличевшегося забора воды остаются из  лишки водных ресурсов, в пределах которых может быть при необходимости уве  личено водопотребление сверх установленных на эти периоды лимитов. 4) Разработка дополнительных мероприятий по водообеспечению населе  ния и объектов экономики водными ресурсами в части объемов воды не требует  ся. 2. Балансы Загрязняющих Веществ В Поверхностных Водных Объектах Бассейна Балансы загрязняющих веществ (Зв) в поверхностных водных объектах бассейна (далее балансы Зв) позволяют оценить количество привноса Зв в вод  ные объекты бассейна от точечных и диффузных источников загрязнения как с со  средоточенными, так и с рассредоточенными сточными водами. При расчёте ба  лансов учитывается также и поступление Зв с территорий без антропогенной нагрузки (естественное фоновое загрязнение водных объектов). Расчеты балансов Зв приведены в приложении 2. 17'),
#  Document(metadata={'title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'level': 1, 'parent_title': '', 'start_page': 17, 'end_page': 29, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content=''),
#  Document(metadata={'title': '2.1 Методика расчета балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 19, 'end_page': 20, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='2.1 Методика расчета балансов Зв Расчеты балансов Зв выполнены по формуле (2)  Мв   Мф   Мс   Мд – Ми   Мн тонн год, (2) где  Мв – поступление Зв с вышерасположенного расчетного участка  Мф – поступление Зв с территории, где отсутствует антропогенная нагруз  ка  Мс – поступление Зв от точечных источников загрязнения  Мд – поступление Зв с территории диффузных источников загрязнения  Ми – изъятие Зв с забором воды. Мн – поступление Зв на нижерасположенный расчетный участок. Мд   Мду   Мдн, тонн год, (3) где  Мду – поступление Зв с территорий диффузных потенциально управля  емых источников загрязнения  Мдн – поступление Зв с территории диффузных неуправляемых источников загрязнения. Мду   Мдпп   Мдсх   Мдгп, тонн год, (4) где  Мдпп – поступление Зв с неканализованной территорий промышленных предприятий и зон их опасного влияния  Мдсх – поступление Зв с территории сельхозпредприятий (животноводче  ские комплексы, фермы, птицефабрики и т.п.)  Мдгп – поступление Зв с неканализованных территорий городских поселе  ний (города и пгт). Мдн   Мдсп   Мдсу   Мдоп   Мдад   Мджд   Мдпо   Мднп   Мдзу, тонн год, (5) где  Мдсп – поступление Зв с территории сельских поселений  Мдсу – поступление Зв с территории сельхозугодий  Мдоп – поступление Зв с территории оленьих пастбищ  Мдад – поступление Зв с территории автодорог  Мджд – поступление Зв с территории железных дорог  Мдпо – поступление Зв с территории свалок Тбо и промотходов  Мднп – поступление Зв с территории нефте  и газопроводов  Мдзу   поступление Зв с территории зон умеренного влияния промышлен  ных предприятий. 19 В формулу расчета баланса включены значения поступления Зв только от тех источников загрязнения водных объектов, которые имеются в пределах рассматриваемого бассейна. Связь между составляющими баланса и обозначениями переменных в формулах представлена в табл. 2.1. Таблица 2.1   строки ба'),
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 3}, page_content='Объём ливневых, талых и фильтрационных сточных вод рассчитан как произведение слоя стока на площадь территории источника загрязнения Wi h х Fi х10 3 (7) где h слой стока с территории источника загрязнения, принятый по слою стока на расчетном водохозяйственном участке, мм год Fi площадь территории i ого источника загрязнения, км2 Значения концентрации Зв в воде, поступающей в водный объект от диффузных источников загрязнения (Cij), получены по материалам исследований различных научных и проектных организаций, литературным источникам, приняты по данным действующих нормативно методических документов, а по некоторым веществам – на основании экспертной оценки. Обоснование принятых значений концентраций Зв в рассредоточенных ливневых и талых сточных водах и объемов сточных вод, а также расчеты по ступления Зв от различных источников загрязнения на расчетный период 2009г. (существующее положение) приведены в Пояснительной записке к Книге 4 (При ложение 6 к Схеме) в прил.3 табл.8 и 29. Полученные величины поступления Зв использованы в расчетах балансов Зв на расчетный уровень 2009г. для водности года 50 и 95 обеспеченности. 2.2 Расчет балансов Зв Балансы Зв на современный уровень выполнены на основе фактических данных 2 Тп водхоз за 2009г. о поступлении Зв в водные объекты с сосредото ченными сточными водами и расчетных величин поступления Зв от диффузных источников загрязнения. В балансе учтены все источники загрязнения (точечные, диффузные управляемые и неуправляемые), а также поступление Зв с террито рий без антропогенной нагрузки. Балансы Зв на перспективу развития экономики 2020г и 2025г. выполне ны с учетом параметров развития Республики Коми и Нао, содержащихся в стратегиях развития субъектов Рф, а также в «Стратегии развития Северо Запад ного федерального округа на период до 2020г.». Расчеты балансов Зв на перспективу выполнены на основе расчета ба лансов Зв на современный расчетный уровень 2009г., к позициям которого приме нялись коэффициенты, учитывающие рост промышленного производства к 2020г. и 2025г. по отношению к современному уровню. Для управляемых источников загрязнения – точечных (сосредоточенные сточные воды) и диффузных потенциально управляемых – учитывалось снижение поступления Зв в водные объекты в соответствии с «Концепцией долгосрочного социально экономического развития Рф на период до 2020г.», утвержденной рас поряжением Правительства Рф от 17.11.2008г., для реализации которой разра 21 ботана «Водная стратегия Рф», утвержденная распоряжением Правительства Рф от 27.08.2009г. 1235 р. Коэффициент снижения рассчитан исходя из уменьше ния к 2020г. значения показателя «Объем организованного сброса загрязняющих веществ в поверхностные водные объекты» до 6.6 млн.тонн по отношению к 2007г. – 11 млн.тонн год (11 6,6 1,7). Для точечных и потенциально управля емых диффузных источников загрязнения коэффициент поступления Зв в 2020г. по отношению к 2009г. принят равным 1,35 (уменьшение понижающего коэффи циента в 2 раза обусловлено тем, что к 2015г. практически никаких мероприятий по снижению поступления Зв в водные объекты водопользователями выполнено не было), к 2025г. – 1,7. Обоснование и расчеты коэффициентов, использованных для перехода от современного расчетного уровня (2009г.) на расчетные уровни 2020г. и 2025г., приведены в приложении 2а. Основной вариант расчета балансов Зв на 2020 и 2025гг. выполнен ис ходя из – «Стратегии социально экономического развития Республики Коми на пе риод до 2020 года» с изменениями от 12.02.2014г., согласно которой объем промышленного производства в республике в 2020 году к уровню 2011 года увели чится в 1,3 раза – проекта «Стратегии социально экономического развития Ненецкого автономного округа на период до 2030г»., по которой к 2030 году рост п ...
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 2, 'total_chunks': 3}, page_content='проекта «Стратегии социально экономического развития Ненецкого автономного округа на период до 2030г»., по которой к 2030 году рост промышлен ного производства Нао составит 2,48 (к 2020 году – 1,8). Данные коэффициенты применялись для определения поступления Зв в водные объекты от всех источников загрязнения (точечных и диффузных) в 2020г. по отношению к современному уровню развития экономики 2009г. Для управля емых источников загрязнения – точечных и диффузных потенциально управля емых – учитывалось снижение поступления Зв в водные объекты в результате природоохранных мероприятий к 2020г в 1,35 раза. Для расчета балансов Зв на расчетный уровень 2025г. принято, что темпы роста промышленного производства сохраняются теми же, что и к 2020 году, а снижение поступления Зв за счет реализации Водной стратегии Рв и прекраще ния сброса сточных вод без очистки и недостаточно очищенных составляет 1,7 раза по отношению к современному уровню (2009г.). Обоснование принятого варианта развития экономики республики Коми и Нао как основного. Для республики Коми и Нао, согласно их стратегиям социально экономического развития и стратегии развития Сзфо на период до 2020г., предусмотрен экономический рост, обеспеченный ресурсной базой этих субъектов Рф и планами освоения энергетического потенциала страны в целом. Согласно Стратегии развития Республики Коми, объем промышленного производства в республике в 2020 году к уровню 2011 года увеличится в 1,3 раза. Среднегодовой прирост составит в среднем около 3,2 процента в год (раздел V Стратегии). 22 Увеличение объемов производства обеспечат большинство видов деятель ности промышленности. При этом доля обрабатывающих производств в структуре промышленного производства к 2020 году составит 43,8 процента против 36 процентов в 2011 году. Современное состояние разрабатываемых на территории республики неф тяных месторождений позволяет предположить умеренный рост объемов добычи нефти, включая газовый конденсат, к 2020 году до уровня 14,4 млн. тонн, или 107,8 процента к уровню 2011 года. Ожидается стабилизация объемов добычи газа на уровне 3 млн. кубических метров в год. Дальнейшие перспективы развития газовой промышленности во многом связаны со строительством газотранспортной системы "Ямал Европа" через территорию Республики Коми, реализация которого позволит вовлечь в раз работку мелкие газовые месторождения и приведет к переоценке перспектив раз вития газодобычи в районах западного склона Полярного и Приполярного Урала. В нефтеперерабатывающей промышленности за счет внедрения новых прогрессивных технологий и увеличения глубины переработки углеводородного сырья сохранится положительная динамика производства основных видов неф тепродуктов. В 2020 году объем производства автомобильного бензина составит 625 тыс. тонн, дизельного топлива 2100 тыс. тонн. Стабилизация развития угольной промышленности Республики Коми, освоение новых месторождений и строительство новых шахт, проведение работ по подготовке нижних горизонтов добычи угля, внедрение высокопроизводитель ного оборудования и проведение мероприятий по снижению простоев производ ства позволят обеспечить добычу угля к 2020 году в объеме 20 млн. тонн. Дальнейшее развитие получит горнорудный комплекс. Увеличение объемов добычи горнорудного сырья связано с созданием в республике новых перераба тывающих производств (строительство глиноземного завода) и дальнейшим раз витием инфраструктуры действующих предприятий. В лесопромышленном комплексе реализация основных задач и направле ний развития позволит обеспечить рациональное и комплексное использование лесных ресурсов республики, увеличить объемы выпуска конкурентоспособной продукции за счет проведения модернизации лесной и перерабатывающей инфраструктуры, увеличения объемов л ...
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 3, 'total_chunks': 3}, page_content='евесно стружечных плит в 1,1 раза. В агропромышленном комплексе республики решение поставленных задач позволит обеспечить рентабельную работу 84 процентов сельскохозяйственных организаций. 23'),
#  Document(metadata={'title': '2.3. Анализ результатов расчетов балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 24, 'end_page': 28, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='При благоприятных внешних и внутренних условиях прирост производства продукции сельского хозяйства в 2020 году к уровню 2011 года составит 13,6 процента. Производство скота и птицы (в живом весе) к 2020 году возрастет к уровню 2011 года на 26,7 процента, молока   на 12,5 процента. Динамичное развитие получит рыболовство и рыбоводство. Реализация ме  роприятий позволит сохранить уровень и доступность для населения ценных ви  дов рыб в районах традиционного рыболовства. Производство товарной рыбы увеличится к 2020 году относительно 2011 года в 1,4 раза. Согласно Проекта «Стратегии социально экономического развития Ненец  кого автономного округа до 2030г» объем промышленного производства округа к 2025 г. увеличится по сравнению с 2007г. в 2,48 раза. Исходя из сценария разви  тия региона на долгосрочный период, предполагается стабильный ежегодный экономический рост в 4 6 процентов по отношению к предыдущему году. Дополнительные варианты расчета балансов Зв на 2020г. для разных уровней перспективного развития экономики выполнен исходя из параметров развития экономики, заложенных в «Стратегии развития Северо Западного фе  дерального округа на период до 2020г.». В Стратегии рассмотрены три варианта перспективного развития – песси  мистический, оптимистический и базовый. При этом параметры базового варианта развития экономики региона близки к параметрам оптимистического варианта. В выполненных расчетах балансов Зв для республики Коми и Нао приме  няется единый коэффициент, соответствующий варианту развития Сзфо. Выкопировка из «Стратегии социально экономического развития Северо Западно  го федерального округа на период до 2020г.» и расчет коэффициентов для песси  мистического, оптимистического и базового вариантов развития экономики регио  на приведены в приложении 2а. Расчет вариантов расчета балансов Зв на разные уровни перспективного развития экономики региона приведены в Прил. к Пз, прил.6 табл.1 12. 2.3. Анализ результатов расчетов балансов Зв Балансы Зв рассчитаны по 20 расчетным, 6 водохозяйственным участ  кам, подбассейнам и бассейну в целом. Расчет выполнен для среднего по водно  сти (50  обесп.) и очень маловодного (95  обесп.) года. Расчетный уровень хо  зяйственного освоения бассейна – современный (2009г.) и перспектива (2020г., 2025г.). Расчет выполнен на основе действующих методических и нормативных документов согласно методике, изложенной в п.2.1. В расчете не учитывались эффекты бионакопления, осаждения Зв, транс  формации их и т.п. ввиду отсутствия соответствующих методик и пособий. По 24 этой же причине также не учитывалось поступление Зв от вторичных источников загрязнения (донные отложения). Однако, несмотря на эти обстоятельства, ба  лансы Зв достоверно отражают основные источники загрязнения и степень ан  тропогенной нагрузки на водные объекты. Анализ результатов балансов Зв выполнен по варианту расчета со следу  ющими условиями  расчет для 6 ти водохозяйственных участков для очень ма  ловодного года (95  обесп.), расчетный уровень – существующее положение 2009г. Оценка вклада отдельных источников загрязнения в суммарное поступле  ние Зв в водные объекты от всех источников (в год 95  обеспеченности) дана в таблице 2.2. Таблица 2.2 Оценка вклада отдельных источников загрязнения в суммарное поступление Зв'),
#  Document(metadata={'title': '2.4 Выводы', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 29, 'end_page': 29, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='2.4 Выводы 1) Основной объем стока с территории бассейна в водные объекты при  ходится на поверхностный дождевой и талый сток с незагрязненных территорий (92  от суммарного объема стока на участке). Поступление веществ двойного ге  незиса в водные объекты также более чем на 90  обусловлено поступлением их с незагрязненных территорий за счет природного содержания в воде. 2) Основной вклад в суммарное поступление Зв в водные объекты – от 78 до 90  приходится на диффузные управляемые источники загрязнения, при этом от 76 до 90  приходится на долю территорий промышленных предприятий и зон их влияния. 3) Сосредоточенные источники загрязнения водных объектов – водовыпус  ки предприятий – вносят до 1,5  от суммарного поступления Зв на в х участке, при этом локально они могут оказывать значительное негативное воздействие на водные объекты вследствие содержания в сточных водах загрязняющих веществ в концентрациях, превышающих допустимые значения. 4) Исходя из вклада различных источников в суммарное загрязнение вод, существенного снижения поступления загрязняющих веществ в водные объекты можно добиться, реализуя в первую очередь мероприятия по снижению поступле  ния Зв от диффузных источников  – перехват загрязненного стока с территорий диффузных потенциально управляемых источников загрязнения (строительство ливневой канализации или перехват стока сетью канав на наиболее загрязненных участках территорий) с очисткой стока перед поступлением его в водные объекты  – ликвидация источников загрязнения на территориях, прилегающих к вод  ным объектам, путем их выноса за пределы водоохранных зон (Воз) и прибреж  ных защитных полос (Пзп) водных объектов  – установление и организация на местности Воз и Пзп водных объектов. Указанные мероприятия содержатся в программе мероприятий в Книге 6 Схемы в составе мероприятий по охране водных объектов от загрязнения, засоре  ния и заиления (группа мероприятий по улучшению оперативного управления за использованием и охраной водных объектов). 5) Таким образом, результаты балансов Зв служат обоснованием необхо  димости разработки мероприятий по снижению поступления Зв от конкретных ис  точников загрязнения, позволяют установить очередность выполнения мероприя  тий с целью достижения максимальной их эффективности и улучшения состояния экосистем и водных объектов в кратчайшие сроки. 29'),
#  Document(metadata={'title': 'Приложение 1', 'level': 1, 'parent_title': '', 'start_page': 30, 'end_page': 273, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1}, page_content='Приложение 1 Водохозяйственные балансы по водохозяйственным участкам бассейна р.Печоры для лет различной водности на расчетные уровни 2008 (современный уровень), 2015, 2020, 2025гг. (перспективный уровень). Таблицы 1   36 30 Таблица 1 Водохозяйственные балансы по водохозяйственным участкам бассейна реки Печоры')]

# %% [markdown]
# ### Добавление метаданных

# %%
# Добавляем порядковый номер в метаданные
for idx, doc in enumerate(processed_documents, start=1):
    doc.metadata['order'] = int(idx)
    doc.metadata['basin'] = 'Печора'

processed_documents
# Out:
# [Document(metadata={'title': 'ВВЕДЕНИЕ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 8, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 1, 'basin': 'Печора'}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8'),
#  Document(metadata={'title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'level': 1, 'parent_title': '', 'start_page': 8, 'end_page': 16, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 2, 'basin': 'Печора'}, page_content=''),
#  Document(metadata={'title': '1.1. Методика расчета водохозяйственных балансов', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 8, 'end_page': 11, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 3, 'basin': 'Печора'}, page_content='Введение В книге 4 «Схемы комплексного использования и охраны водных объектов, включая Ндв, бассейна реки Печоры» (далее Схема) представлены расчеты водохозяйственных балансов и балансов загрязняющих веществ, выполненные по расчетным и водохозяйственным участкам для лет различной водности (50 , 75  и 95  обеспеченности). Кроме того, в книге приведены расчеты величин пре  дельного изъятия воды из поверхностных водных объектов, которые были исполь  зованы в расчетах водохозяйственных балансов. Представленные материалы служат обоснованием необходимости выпол  нения водохозяйственных и водоохранных мероприятий для решения проблем водохозяйственного комплекса. 1. Водохозяйственные Балансы 1.1. Методика расчета водохозяйственных балансов В качестве методической основы расчета водохозяйственных балансов принята «Методика расчёта водохозяйственных балансов водных объектов», утвержденная приказом Мпр России от 30.11.2007г.   314. Водохозяйственный баланс является итогом водохозяйственных расчетов, осуществляемых при подготовке водохозяйственного обоснования Схем, и опре  деляет соотношение располагаемых водных ресурсов (объемов поверхностных и подземных вод, доступных для многолетнего гарантированного использования при существующем и проектируемом составе водохозяйственного комплекса) и расчетного водопотребления при прогнозируемом уровне развития экономики. Баланс воды в замыкающем расчетный участок створе рассчитывается как разность приходной и расходной части по формуле (1)  В   Wвх   Wоспр   Wбок   Wпзв   Wвв   Wдот ± Wу   Wпер   Wвдп – Wэ   Wус (1) 8 Таблица 1.1 Составляющие расчета баланса (приходной, расходной и балансовой частей)'),
#  Document(metadata={'title': '1.2. Водохозяйственное районирование бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 12, 'end_page': 14, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 4, 'basin': 'Печора'}, page_content='1.2. Водохозяйственное районирование бассейна реки Печоры Водохозяйственное районирование бассейна дано на рис.1. В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй  ственных участков, назначенных на реках бассейна (табл.1), характеристики ство  ров, замыкающих водохозяйственные участки (табл.2). Таблица 1 к рис.1'),
#  Document(metadata={'title': '1.3. Водные ресурсы бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 15, 'end_page': 15, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 5, 'basin': 'Печора'}, page_content='Таблица 2 к рис.1'),
#  Document(metadata={'title': '1.4. Расчеты водохозяйственных балансов для лет различной водности', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 16, 'end_page': 16, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 6, 'basin': 'Печора'}, page_content='Книге 4 (Прилож.6 к Скиово), приложение 1 табл.1 и приложение 2 табл.1 соответственно. 1.4. Расчеты водохозяйственных балансов для лет различной водности Расчёты водохозяйственных балансов по расчетным водохозяйственным участкам бассейна, подбассейнам и бассейну в целом выполнены на расчетные уровни 2008г. (современный уровень), 2015г., 2020г. и 2025г. (перспектива). В качестве современного расчетного уровня принят 2008г., поскольку за предыдущие 3 года водопользование в бассейне по данным 2 Тп водхоз характе  ризовалось наибольшими величинами в 2008 году. Расчёты выполнялись для характерных по водности лет – среднему (50  обеспеченности), маловодному (75 обесп.) и исключительно маловодному (95 обесп.). В качестве расчетных периодов приняты    Водохозяйственный год  с мая по апрель,   Нелимитирующий период (весна) – с мая по июль,   Лимитирующие  период – с августа по апрель, сезон (зима) – с декабря по апрель, месяцы  зимний – март, летне осенний – ноябрь. В расчете водохозяйственных балансов использовались следующие исход  ные данные  – поверхностные водные ресурсы в створах, замыкающих водохозяйственные и расчётные в х участки (приведены в Пояснительной записке к Книге 4 (При  лож.6 к Скиово), таблицы 1 приложений 1 и 2)  – объемы водопотребления и водоотведения на современный уровень 2008г. (базовый), полученные на основании данных статотчетности 2 Тп водхоз, предоставленных Двинско Печорским Бассейновым водным управлением (Бву) (приведены в Пояснительной записке к Книге 4, таблицы 2 приложений 1 и 2)  – водопользование на перспективу 2015г., 2020г. и 2025г. (приведено в Поясни  тельной записке к Книге 4 (Прилож.6 к Скиово), таблицы 3 5 приложения 1)  – экологический сток, определен  – для нелимитирующего периода  в зависимости от водности года как процент от объема естественного поверхностного стока в створе, замы  кающем расчетный водохозяйственный участок – для года 50  обеспе  ченности – 80  , 75  обесп.– 85  и год 95  обесп. – 90  от естествен  ного объема стока  – для лимитирующего периода  лето осень – 75  от стока минимального летнего месяца и зима – 75  от стока минимального зимнего месяца (в 16'),
#  Document(metadata={'title': '1.5. Выводы', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 17, 'end_page': 17, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 7, 'basin': 'Печора'}, page_content='отдельных случаях выполнена корректировка экологического стока исхо  дя из конкретных условий водопользования), млн.м3. Величины экологического стока приведены в Пояснительной записке к Книге 4 (Прилож.6 к Скиово), таблице 6 приложения 1 и таблицах 5 7 приложения 2. Расчеты водохозяйственных балансов для лет различной водности в современных условиях и на перспективу развития экономики представлены в при  ложении 1 табл.1  36    по водохозяйственным участкам (табл. 1 12)    по подбассейну (табл. 13 – 24)   по бассейну (табл. 25 – 36). 1.5. Выводы 1) Приведенный метод расчета балансов позволяет оценить использование водных ресурсов, выявить участки с излишками или дефицитом водных ресурсов и при необходимости разработать мероприятия для покрытия дефицитов. 2) Бассейн р.Печоры полностью водообеспечен по объему поверхност  ных и подземных водных ресурсов  дефицитов воды не выявлено ни по одному водохозяйственному или расчетному участку с учетом обеспечения расходов воды в водных объектах, требуемых для покрытия экологического стока и стока, обеспечивающего условия судоходства. 3) Расчет в х балансов на перспективу 2015, 2020 и 2025гг. показал, что уве  личение забора водных ресурсов в рамках установленных на перспективу лими  тов не приводит к возникновению дефицитов водных ресурсов (т.е. результаты балансов могут считаться обоснованием установленных в Схеме лимитов забора (изъятия) водных ресурсов). С учетом увеличевшегося забора воды остаются из  лишки водных ресурсов, в пределах которых может быть при необходимости уве  личено водопотребление сверх установленных на эти периоды лимитов. 4) Разработка дополнительных мероприятий по водообеспечению населе  ния и объектов экономики водными ресурсами в части объемов воды не требует  ся. 2. Балансы Загрязняющих Веществ В Поверхностных Водных Объектах Бассейна Балансы загрязняющих веществ (Зв) в поверхностных водных объектах бассейна (далее балансы Зв) позволяют оценить количество привноса Зв в вод  ные объекты бассейна от точечных и диффузных источников загрязнения как с со  средоточенными, так и с рассредоточенными сточными водами. При расчёте ба  лансов учитывается также и поступление Зв с территорий без антропогенной нагрузки (естественное фоновое загрязнение водных объектов). Расчеты балансов Зв приведены в приложении 2. 17'),
#  Document(metadata={'title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'level': 1, 'parent_title': '', 'start_page': 17, 'end_page': 29, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 8, 'basin': 'Печора'}, page_content=''),
#  Document(metadata={'title': '2.1 Методика расчета балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 19, 'end_page': 20, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 9, 'basin': 'Печора'}, page_content='2.1 Методика расчета балансов Зв Расчеты балансов Зв выполнены по формуле (2)  Мв   Мф   Мс   Мд – Ми   Мн тонн год, (2) где  Мв – поступление Зв с вышерасположенного расчетного участка  Мф – поступление Зв с территории, где отсутствует антропогенная нагруз  ка  Мс – поступление Зв от точечных источников загрязнения  Мд – поступление Зв с территории диффузных источников загрязнения  Ми – изъятие Зв с забором воды. Мн – поступление Зв на нижерасположенный расчетный участок. Мд   Мду   Мдн, тонн год, (3) где  Мду – поступление Зв с территорий диффузных потенциально управля  емых источников загрязнения  Мдн – поступление Зв с территории диффузных неуправляемых источников загрязнения. Мду   Мдпп   Мдсх   Мдгп, тонн год, (4) где  Мдпп – поступление Зв с неканализованной территорий промышленных предприятий и зон их опасного влияния  Мдсх – поступление Зв с территории сельхозпредприятий (животноводче  ские комплексы, фермы, птицефабрики и т.п.)  Мдгп – поступление Зв с неканализованных территорий городских поселе  ний (города и пгт). Мдн   Мдсп   Мдсу   Мдоп   Мдад   Мджд   Мдпо   Мднп   Мдзу, тонн год, (5) где  Мдсп – поступление Зв с территории сельских поселений  Мдсу – поступление Зв с территории сельхозугодий  Мдоп – поступление Зв с территории оленьих пастбищ  Мдад – поступление Зв с территории автодорог  Мджд – поступление Зв с территории железных дорог  Мдпо – поступление Зв с территории свалок Тбо и промотходов  Мднп – поступление Зв с территории нефте  и газопроводов  Мдзу   поступление Зв с территории зон умеренного влияния промышлен  ных предприятий. 19 В формулу расчета баланса включены значения поступления Зв только от тех источников загрязнения водных объектов, которые имеются в пределах рассматриваемого бассейна. Связь между составляющими баланса и обозначениями переменных в формулах представлена в табл. 2.1. Таблица 2.1   строки ба'),
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 3, 'order': 10, 'basin': 'Печора'}, page_content='Объём ливневых, талых и фильтрационных сточных вод рассчитан как произведение слоя стока на площадь территории источника загрязнения Wi h х Fi х10 3 (7) где h слой стока с территории источника загрязнения, принятый по слою стока на расчетном водохозяйственном участке, мм год Fi площадь территории i ого источника загрязнения, км2 Значения концентрации Зв в воде, поступающей в водный объект от диффузных источников загрязнения (Cij), получены по материалам исследований различных научных и проектных организаций, литературным источникам, приняты по данным действующих нормативно методических документов, а по некоторым веществам – на основании экспертной оценки. Обоснование принятых значений концентраций Зв в рассредоточенных ливневых и талых сточных водах и объемов сточных вод, а также расчеты по ступления Зв от различных источников загрязнения на расчетный период 2009г. (существующее положение) приведены в Пояснительной записке к Книге 4 (При ложение 6 к Схеме) в прил.3 табл.8 и 29. Полученные величины поступления Зв использованы в расчетах балансов Зв на расчетный уровень 2009г. для водности года 50 и 95 обеспеченности. 2.2 Расчет балансов Зв Балансы Зв на современный уровень выполнены на основе фактических данных 2 Тп водхоз за 2009г. о поступлении Зв в водные объекты с сосредото ченными сточными водами и расчетных величин поступления Зв от диффузных источников загрязнения. В балансе учтены все источники загрязнения (точечные, диффузные управляемые и неуправляемые), а также поступление Зв с террито рий без антропогенной нагрузки. Балансы Зв на перспективу развития экономики 2020г и 2025г. выполне ны с учетом параметров развития Республики Коми и Нао, содержащихся в стратегиях развития субъектов Рф, а также в «Стратегии развития Северо Запад ного федерального округа на период до 2020г.». Расчеты балансов Зв на перспективу выполнены на основе расчета ба лансов Зв на современный расчетный уровень 2009г., к позициям которого приме нялись коэффициенты, учитывающие рост промышленного производства к 2020г. и 2025г. по отношению к современному уровню. Для управляемых источников загрязнения – точечных (сосредоточенные сточные воды) и диффузных потенциально управляемых – учитывалось снижение поступления Зв в водные объекты в соответствии с «Концепцией долгосрочного социально экономического развития Рф на период до 2020г.», утвержденной рас поряжением Правительства Рф от 17.11.2008г., для реализации которой разра 21 ботана «Водная стратегия Рф», утвержденная распоряжением Правительства Рф от 27.08.2009г. 1235 р. Коэффициент снижения рассчитан исходя из уменьше ния к 2020г. значения показателя «Объем организованного сброса загрязняющих веществ в поверхностные водные объекты» до 6.6 млн.тонн по отношению к 2007г. – 11 млн.тонн год (11 6,6 1,7). Для точечных и потенциально управля емых диффузных источников загрязнения коэффициент поступления Зв в 2020г. по отношению к 2009г. принят равным 1,35 (уменьшение понижающего коэффи циента в 2 раза обусловлено тем, что к 2015г. практически никаких мероприятий по снижению поступления Зв в водные объекты водопользователями выполнено не было), к 2025г. – 1,7. Обоснование и расчеты коэффициентов, использованных для перехода от современного расчетного уровня (2009г.) на расчетные уровни 2020г. и 2025г., приведены в приложении 2а. Основной вариант расчета балансов Зв на 2020 и 2025гг. выполнен ис ходя из – «Стратегии социально экономического развития Республики Коми на пе риод до 2020 года» с изменениями от 12.02.2014г., согласно которой объем промышленного производства в республике в 2020 году к уровню 2011 года увели чится в 1,3 раза – проекта «Стратегии социально экономического развития Ненецкого автономного округа на период до 2030г» ...
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 2, 'total_chunks': 3, 'order': 11, 'basin': 'Печора'}, page_content='проекта «Стратегии социально экономического развития Ненецкого автономного округа на период до 2030г»., по которой к 2030 году рост промышлен ного производства Нао составит 2,48 (к 2020 году – 1,8). Данные коэффициенты применялись для определения поступления Зв в водные объекты от всех источников загрязнения (точечных и диффузных) в 2020г. по отношению к современному уровню развития экономики 2009г. Для управля емых источников загрязнения – точечных и диффузных потенциально управля емых – учитывалось снижение поступления Зв в водные объекты в результате природоохранных мероприятий к 2020г в 1,35 раза. Для расчета балансов Зв на расчетный уровень 2025г. принято, что темпы роста промышленного производства сохраняются теми же, что и к 2020 году, а снижение поступления Зв за счет реализации Водной стратегии Рв и прекраще ния сброса сточных вод без очистки и недостаточно очищенных составляет 1,7 раза по отношению к современному уровню (2009г.). Обоснование принятого варианта развития экономики республики Коми и Нао как основного. Для республики Коми и Нао, согласно их стратегиям социально экономического развития и стратегии развития Сзфо на период до 2020г., предусмотрен экономический рост, обеспеченный ресурсной базой этих субъектов Рф и планами освоения энергетического потенциала страны в целом. Согласно Стратегии развития Республики Коми, объем промышленного производства в республике в 2020 году к уровню 2011 года увеличится в 1,3 раза. Среднегодовой прирост составит в среднем около 3,2 процента в год (раздел V Стратегии). 22 Увеличение объемов производства обеспечат большинство видов деятель ности промышленности. При этом доля обрабатывающих производств в структуре промышленного производства к 2020 году составит 43,8 процента против 36 процентов в 2011 году. Современное состояние разрабатываемых на территории республики неф тяных месторождений позволяет предположить умеренный рост объемов добычи нефти, включая газовый конденсат, к 2020 году до уровня 14,4 млн. тонн, или 107,8 процента к уровню 2011 года. Ожидается стабилизация объемов добычи газа на уровне 3 млн. кубических метров в год. Дальнейшие перспективы развития газовой промышленности во многом связаны со строительством газотранспортной системы "Ямал Европа" через территорию Республики Коми, реализация которого позволит вовлечь в раз работку мелкие газовые месторождения и приведет к переоценке перспектив раз вития газодобычи в районах западного склона Полярного и Приполярного Урала. В нефтеперерабатывающей промышленности за счет внедрения новых прогрессивных технологий и увеличения глубины переработки углеводородного сырья сохранится положительная динамика производства основных видов неф тепродуктов. В 2020 году объем производства автомобильного бензина составит 625 тыс. тонн, дизельного топлива 2100 тыс. тонн. Стабилизация развития угольной промышленности Республики Коми, освоение новых месторождений и строительство новых шахт, проведение работ по подготовке нижних горизонтов добычи угля, внедрение высокопроизводитель ного оборудования и проведение мероприятий по снижению простоев производ ства позволят обеспечить добычу угля к 2020 году в объеме 20 млн. тонн. Дальнейшее развитие получит горнорудный комплекс. Увеличение объемов добычи горнорудного сырья связано с созданием в республике новых перераба тывающих производств (строительство глиноземного завода) и дальнейшим раз витием инфраструктуры действующих предприятий. В лесопромышленном комплексе реализация основных задач и направле ний развития позволит обеспечить рациональное и комплексное использование лесных ресурсов республики, увеличить объемы выпуска конкурентоспособной продукции за счет проведения модернизации лесной и перерабатывающей инфр ...
#  Document(metadata={'title': '2.2 Расчет балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 21, 'end_page': 23, 'file': 'Книга_4.json', 'chunk_index': 3, 'total_chunks': 3, 'order': 12, 'basin': 'Печора'}, page_content='евесно стружечных плит в 1,1 раза. В агропромышленном комплексе республики решение поставленных задач позволит обеспечить рентабельную работу 84 процентов сельскохозяйственных организаций. 23'),
#  Document(metadata={'title': '2.3. Анализ результатов расчетов балансов ЗВ', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 24, 'end_page': 28, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 13, 'basin': 'Печора'}, page_content='При благоприятных внешних и внутренних условиях прирост производства продукции сельского хозяйства в 2020 году к уровню 2011 года составит 13,6 процента. Производство скота и птицы (в живом весе) к 2020 году возрастет к уровню 2011 года на 26,7 процента, молока   на 12,5 процента. Динамичное развитие получит рыболовство и рыбоводство. Реализация ме  роприятий позволит сохранить уровень и доступность для населения ценных ви  дов рыб в районах традиционного рыболовства. Производство товарной рыбы увеличится к 2020 году относительно 2011 года в 1,4 раза. Согласно Проекта «Стратегии социально экономического развития Ненец  кого автономного округа до 2030г» объем промышленного производства округа к 2025 г. увеличится по сравнению с 2007г. в 2,48 раза. Исходя из сценария разви  тия региона на долгосрочный период, предполагается стабильный ежегодный экономический рост в 4 6 процентов по отношению к предыдущему году. Дополнительные варианты расчета балансов Зв на 2020г. для разных уровней перспективного развития экономики выполнен исходя из параметров развития экономики, заложенных в «Стратегии развития Северо Западного фе  дерального округа на период до 2020г.». В Стратегии рассмотрены три варианта перспективного развития – песси  мистический, оптимистический и базовый. При этом параметры базового варианта развития экономики региона близки к параметрам оптимистического варианта. В выполненных расчетах балансов Зв для республики Коми и Нао приме  няется единый коэффициент, соответствующий варианту развития Сзфо. Выкопировка из «Стратегии социально экономического развития Северо Западно  го федерального округа на период до 2020г.» и расчет коэффициентов для песси  мистического, оптимистического и базового вариантов развития экономики регио  на приведены в приложении 2а. Расчет вариантов расчета балансов Зв на разные уровни перспективного развития экономики региона приведены в Прил. к Пз, прил.6 табл.1 12. 2.3. Анализ результатов расчетов балансов Зв Балансы Зв рассчитаны по 20 расчетным, 6 водохозяйственным участ  кам, подбассейнам и бассейну в целом. Расчет выполнен для среднего по водно  сти (50  обесп.) и очень маловодного (95  обесп.) года. Расчетный уровень хо  зяйственного освоения бассейна – современный (2009г.) и перспектива (2020г., 2025г.). Расчет выполнен на основе действующих методических и нормативных документов согласно методике, изложенной в п.2.1. В расчете не учитывались эффекты бионакопления, осаждения Зв, транс  формации их и т.п. ввиду отсутствия соответствующих методик и пособий. По 24 этой же причине также не учитывалось поступление Зв от вторичных источников загрязнения (донные отложения). Однако, несмотря на эти обстоятельства, ба  лансы Зв достоверно отражают основные источники загрязнения и степень ан  тропогенной нагрузки на водные объекты. Анализ результатов балансов Зв выполнен по варианту расчета со следу  ющими условиями  расчет для 6 ти водохозяйственных участков для очень ма  ловодного года (95  обесп.), расчетный уровень – существующее положение 2009г. Оценка вклада отдельных источников загрязнения в суммарное поступле  ние Зв в водные объекты от всех источников (в год 95  обеспеченности) дана в таблице 2.2. Таблица 2.2 Оценка вклада отдельных источников загрязнения в суммарное поступление Зв'),
#  Document(metadata={'title': '2.4 Выводы', 'level': 2, 'parent_title': '2. БАЛАНСЫ ЗАГРЯЗНЯЮЩИХ ВЕЩЕСТВ В ПОВЕРХНОСТНЫХ', 'start_page': 29, 'end_page': 29, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 14, 'basin': 'Печора'}, page_content='2.4 Выводы 1) Основной объем стока с территории бассейна в водные объекты при  ходится на поверхностный дождевой и талый сток с незагрязненных территорий (92  от суммарного объема стока на участке). Поступление веществ двойного ге  незиса в водные объекты также более чем на 90  обусловлено поступлением их с незагрязненных территорий за счет природного содержания в воде. 2) Основной вклад в суммарное поступление Зв в водные объекты – от 78 до 90  приходится на диффузные управляемые источники загрязнения, при этом от 76 до 90  приходится на долю территорий промышленных предприятий и зон их влияния. 3) Сосредоточенные источники загрязнения водных объектов – водовыпус  ки предприятий – вносят до 1,5  от суммарного поступления Зв на в х участке, при этом локально они могут оказывать значительное негативное воздействие на водные объекты вследствие содержания в сточных водах загрязняющих веществ в концентрациях, превышающих допустимые значения. 4) Исходя из вклада различных источников в суммарное загрязнение вод, существенного снижения поступления загрязняющих веществ в водные объекты можно добиться, реализуя в первую очередь мероприятия по снижению поступле  ния Зв от диффузных источников  – перехват загрязненного стока с территорий диффузных потенциально управляемых источников загрязнения (строительство ливневой канализации или перехват стока сетью канав на наиболее загрязненных участках территорий) с очисткой стока перед поступлением его в водные объекты  – ликвидация источников загрязнения на территориях, прилегающих к вод  ным объектам, путем их выноса за пределы водоохранных зон (Воз) и прибреж  ных защитных полос (Пзп) водных объектов  – установление и организация на местности Воз и Пзп водных объектов. Указанные мероприятия содержатся в программе мероприятий в Книге 6 Схемы в составе мероприятий по охране водных объектов от загрязнения, засоре  ния и заиления (группа мероприятий по улучшению оперативного управления за использованием и охраной водных объектов). 5) Таким образом, результаты балансов Зв служат обоснованием необхо  димости разработки мероприятий по снижению поступления Зв от конкретных ис  точников загрязнения, позволяют установить очередность выполнения мероприя  тий с целью достижения максимальной их эффективности и улучшения состояния экосистем и водных объектов в кратчайшие сроки. 29'),
#  Document(metadata={'title': 'Приложение 1', 'level': 1, 'parent_title': '', 'start_page': 30, 'end_page': 273, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 15, 'basin': 'Печора'}, page_content='Приложение 1 Водохозяйственные балансы по водохозяйственным участкам бассейна р.Печоры для лет различной водности на расчетные уровни 2008 (современный уровень), 2015, 2020, 2025гг. (перспективный уровень). Таблицы 1   36 30 Таблица 1 Водохозяйственные балансы по водохозяйственным участкам бассейна реки Печоры')]

# %% [markdown]
# ### Векторизация Qdrant

# %%
# Сортировка документов перед загрузкой
processed_documents = sorted(processed_documents, key=lambda x: x.metadata['order'])

# %%
import uuid
import time
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, VectorParams
from sentence_transformers import SentenceTransformer

# 1. Подключение к Qdrant
client = QdrantClient(url="http://localhost:6333")

# 2. Загрузка модели SentenceTransformer
model_name = "deepvk/USER-bge-m3"  # Укажите модель, которая вам нужна
model = SentenceTransformer(model_name)

# 3. Проверяем, существует ли коллекция
collection_name = "testing_4_pechora"

try:
    # Проверяем существование коллекции
    collections = client.get_collections().collections  # Используем атрибут `.collections`
    if not any(c.name == collection_name for c in collections):
        # Если коллекция не существует, создаём новую
        vector_size = model.get_sentence_embedding_dimension()
        client.create_collection(
            collection_name=collection_name,
            vectors_config=VectorParams(size=vector_size, distance="Cosine"),
        )
        print(f"Коллекция '{collection_name}' была создана.")
    else:
        print(f"Коллекция '{collection_name}' уже существует. Новые данные будут добавлены.")
except Exception as e:
    print(f"Ошибка при проверке коллекции: {e}")

# 4. Векторизация и загрузка новых данных в коллекцию
points = []
for doc in processed_documents:
    vector = model.encode(doc.page_content).tolist()
    point = PointStruct(
        id=str(uuid.uuid4()),  # Уникальный ID
        vector=vector,
        payload={"content": doc.page_content, **doc.metadata},  # Сохраняем текст и метаданные
    )
    points.append(point)

# Используем upsert для добавления данных в коллекцию
time.sleep(2)
try:
    client.upsert(collection_name=collection_name, points=points)
    print("Новые данные успешно добавлены в Qdrant!")
except Exception as e:
    print(f"Ошибка при добавлении данных: {e}")
# Out:
# Коллекция 'testing_4_pechora' была создана.
# Новые данные успешно добавлены в Qdrant!

# %%
# Поиск документов
query = "В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй ственных участков, назначенных на реках бассейна (табл.1), характеристики ство ров, замыкающих водохозяйственные участки"
query_vector = model.encode(query).tolist()  # Векторизация запроса

# Выполняем поиск с использованием фильтрации
search_results = client.search(
    collection_name=collection_name,
    query_vector=query_vector,
    limit=2,  # Количество результатов
    query_filter={  # Используем правильное название параметра
        "must": [{"key": "basin", "match": {"value": "Печора"}}]
    },
)

print(f'Всего найдено: {len(search_results)}')
# Вывод результатов, включая контент
for result in search_results:
    print(f"ID: {result.id}")
    print(f"Score: {result.score}")
    print(f"Content: {result.payload['content']}")
    print(f"Metadata: {result.payload}")
# Out:
# Всего найдено: 2
# ID: 4b125653-328f-4226-87cf-b58c9eba9eba
# Score: 0.8601887
# Content: 1.2. Водохозяйственное районирование бассейна реки Печоры Водохозяйственное районирование бассейна дано на рис.1. В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй  ственных участков, назначенных на реках бассейна (табл.1), характеристики ство  ров, замыкающих водохозяйственные участки (табл.2). Таблица 1 к рис.1
# Metadata: {'content': '1.2. Водохозяйственное районирование бассейна реки Печоры Водохозяйственное районирование бассейна дано на рис.1. В таблицах к рисунку приведены – перечень и основные характеристики расчетных водохозяй  ственных участков, назначенных на реках бассейна (табл.1), характеристики ство  ров, замыкающих водохозяйственные участки (табл.2). Таблица 1 к рис.1', 'title': '1.2. Водохозяйственное районирование бассейна реки Печоры', 'level': 2, 'parent_title': '1. ВОДОХОЗЯЙСТВЕННЫЕ БАЛАНСЫ', 'start_page': 12, 'end_page': 14, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 4, 'basin': 'Печора'}
# ID: b1e1907a-c7af-484f-9fe3-5adc103b73e0
# Score: 0.7320965
# Content: Приложение 1 Водохозяйственные балансы по водохозяйственным участкам бассейна р.Печоры для лет различной водности на расчетные уровни 2008 (современный уровень), 2015, 2020, 2025гг. (перспективный уровень). Таблицы 1   36 30 Таблица 1 Водохозяйственные балансы по водохозяйственным участкам бассейна реки Печоры
# Metadata: {'content': 'Приложение 1 Водохозяйственные балансы по водохозяйственным участкам бассейна р.Печоры для лет различной водности на расчетные уровни 2008 (современный уровень), 2015, 2020, 2025гг. (перспективный уровень). Таблицы 1   36 30 Таблица 1 Водохозяйственные балансы по водохозяйственным участкам бассейна реки Печоры', 'title': 'Приложение 1', 'level': 1, 'parent_title': '', 'start_page': 30, 'end_page': 273, 'file': 'Книга_4.json', 'chunk_index': 1, 'total_chunks': 1, 'order': 15, 'basin': 'Печора'}

# %% [markdown]
# ### Создание коллекций с разными метриками поиска

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams
from sentence_transformers import SentenceTransformer

# 1. Подключение к Qdrant
client = QdrantClient(url="http://localhost:6333")

# 2. Загрузка модели
model_name = "deepvk/USER-bge-m3"
model = SentenceTransformer(model_name)
vector_size = model.get_sentence_embedding_dimension()

# 3. Создание коллекций с разными метриками
metrics = ["Cosine", "Dot", "Euclid", "Manhattan"]
collection_names = {metric: f"documents_{metric.lower()}" for metric in metrics}

for metric, collection_name in collection_names.items():
    client.recreate_collection(
        collection_name=collection_name,
        vectors_config=VectorParams(size=vector_size, distance=metric),
    )

# 4. Загрузка данных в каждую коллекцию
points = [
    PointStruct(
        id=str(uuid.uuid4()),
        vector=model.encode(doc.page_content).tolist(),
        payload={"content": doc.page_content, **doc.metadata},
    )
    for doc in processed_documents
]

for metric, collection_name in collection_names.items():
    client.upsert(collection_name=collection_name, points=points)

print("Documents successfully uploaded to all collections!")
# Out:
# /var/folders/rf/r9_1j8lj3m72m2lv3v1tp3rh0000gn/T/ipykernel_1389/2795548259.py:18: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Documents successfully uploaded to all collections!

# %%
query = "О чем говорится в Таблица 5.63? "
query_vector = model.encode(query).tolist()

# Поиск в каждой коллекции
for metric, collection_name in collection_names.items():
    print(f"Searching in {metric} collection...")
    search_results = client.search(
        collection_name=collection_name,
        query_vector=query_vector,
        limit=5,
    )
    for result in search_results:
        print(f"ID: {result.id}")
        print(f"Score: {result.score}")
        print(f"Content: {result.payload['content']}")
    print("-" * 40)
# Out:
# Searching in Cosine collection...
# ID: e351524f-00bd-4edf-a8f1-1f618ce4989e
# Score: 0.58543724
# Content: Продолжение таблицы 5.25
# ID: 7fc3ec77-baae-4600-8f6c-78ad82ba4dfc
# Score: 0.58543724
# Content: Продолжение таблицы 5.25
# ID: b622549f-1458-4515-b130-23a517d24459
# Score: 0.49149868
# Content: Таблица 5.63   Основные характеристики гидроузлов Рисунок 5.50   Площадь акватории Цимлянского водохранилища при различных отметках у Рисунок 5.51   Забор воды на цели прудового рыбоводства в бассейне р.Дон
# ID: e515229e-c3a2-4c27-8363-b1f46a4d7699
# Score: 0.47579733
# Content: Продолжение таблицы 3.4
# ID: cade3acf-c8ef-4d05-b5f4-2c4c06d0f155
# Score: 0.44613242
# Content: 5.5.2 Водоснабжение Использование водных ресурсов для водоснабжения городов и промышленных предприятий, включая Тэс и Аэс, а также сельских населенных пунктов и обводнения пастбищ на всех расчетных уровнях, имея высокую обеспеченность (Р   95 ), отличается относительно других участников водохозяйственного комплекса, незначительной величиной безвозвратного изъятия стока (около 7.5 ). Около 50  суммарного объема коммунально бытового и промышленного водопотребления приходится на Верхний Дон (до створа г.Лиски), где размещены крупные промышленные центры г.г.Липецк и Воронеж. На Нижнем Дону – от г.Калач на Дону до устья расположены водозаборы крупных городов Ростовской области – Волгодонска, Новочеркасска, Шахт, Ростова, Таганрога, Азова и др. Наиболее крупным водопользователем на этом участке р.Дон является Новочеркасская Грэс. Источниками коммунально бытового водоснабжения (табл. 5.10) на Нижнем Дону является, в основном, речной сток р.р.Дон и Северский Донец, на Верхнем Дону в интересах водоснабжения широко используются подземные воды, за счет которых покрывается весь потребный объем. Таблица 5.54   Забор воды для использования на цели хозяйственно бытового водоснабжения в Рисунок 5.35   Забор воды из поверхностных водных объектов на цели Рисунок 5.36   Забор воды из подземных водных объектов на цели Рисунок 5.38   Забор воды из поверхностных водных объектов на цели Рисунок 5.39   Забор воды из подземных водных объектов на цели Рисунок 5.40   Сброс сточных вод в поверхностные водные объекты после использования на Рисунок 5.41   Забор воды из поверхностных водных объектов на цели Рисунок 5.42   Забор воды из подземных объектов на цели сельскохозяйственного
# ----------------------------------------
# Searching in Dot collection...
# ID: 7fc3ec77-baae-4600-8f6c-78ad82ba4dfc
# Score: 0.58543724
# Content: Продолжение таблицы 5.25
# ID: e351524f-00bd-4edf-a8f1-1f618ce4989e
# Score: 0.58543724
# Content: Продолжение таблицы 5.25
# ID: b622549f-1458-4515-b130-23a517d24459
# Score: 0.49149868
# Content: Таблица 5.63   Основные характеристики гидроузлов Рисунок 5.50   Площадь акватории Цимлянского водохранилища при различных отметках у Рисунок 5.51   Забор воды на цели прудового рыбоводства в бассейне р.Дон
# ID: e515229e-c3a2-4c27-8363-b1f46a4d7699
# Score: 0.47579733
# Content: Продолжение таблицы 3.4
# ID: cade3acf-c8ef-4d05-b5f4-2c4c06d0f155
# Score: 0.44613242
# Content: 5.5.2 Водоснабжение Использование водных ресурсов для водоснабжения городов и промышленных предприятий, включая Тэс и Аэс, а также сельских населенных пунктов и обводнения пастбищ на всех расчетных уровнях, имея высокую обеспеченность (Р   95 ), отличается относительно других участников водохозяйственного комплекса, незначительной величиной безвозвратного изъятия стока (около 7.5 ). Около 50  суммарного объема коммунально бытового и промышленного водопотребления приходится на Верхний Дон (до створа г.Лиски), где размещены крупные промышленные центры г.г.Липецк и Воронеж. На Нижнем Дону – от г.Калач на Дону до устья расположены водозаборы крупных городов Ростовской области – Волгодонска, Новочеркасска, Шахт, Ростова, Таганрога, Азова и др. Наиболее крупным водопользователем на этом участке р.Дон является Новочеркасская Грэс. Источниками коммунально бытового водоснабжения (табл. 5.10) на Нижнем Дону является, в основном, речной сток р.р.Дон и Северский Донец, на Верхнем Дону в интересах водоснабжения широко используются подземные воды, за счет которых покрывается весь потребный объем. Таблица 5.54   Забор воды для использования на цели хозяйственно бытового водоснабжения в Рисунок 5.35   Забор воды из поверхностных водных объектов на цели Рисунок 5.36   Забор воды из подземных водных объектов на цели Рисунок 5.38   Забор воды из поверхностных водных объектов на цели Рисунок 5.39   Забор воды из подземных водных объектов на цели Рисунок 5.40   Сброс сточных вод в поверхностные водные объекты после использования на Рисунок 5.41   Забор воды из поверхностных водных объектов на цели Рисунок 5.42   Забор воды из подземных объектов на цели сельскохозяйственного
# ----------------------------------------
# Searching in Euclid collection...
# ID: e351524f-00bd-4edf-a8f1-1f618ce4989e
# Score: 0.9105633
# Content: Продолжение таблицы 5.25
# ID: 7fc3ec77-baae-4600-8f6c-78ad82ba4dfc
# Score: 0.9105633
# Content: Продолжение таблицы 5.25
# ID: b622549f-1458-4515-b130-23a517d24459
# Score: 1.0084654
# Content: Таблица 5.63   Основные характеристики гидроузлов Рисунок 5.50   Площадь акватории Цимлянского водохранилища при различных отметках у Рисунок 5.51   Забор воды на цели прудового рыбоводства в бассейне р.Дон
# ID: e515229e-c3a2-4c27-8363-b1f46a4d7699
# Score: 1.0239166
# Content: Продолжение таблицы 3.4
# ID: cade3acf-c8ef-4d05-b5f4-2c4c06d0f155
# Score: 1.0524899
# Content: 5.5.2 Водоснабжение Использование водных ресурсов для водоснабжения городов и промышленных предприятий, включая Тэс и Аэс, а также сельских населенных пунктов и обводнения пастбищ на всех расчетных уровнях, имея высокую обеспеченность (Р   95 ), отличается относительно других участников водохозяйственного комплекса, незначительной величиной безвозвратного изъятия стока (около 7.5 ). Около 50  суммарного объема коммунально бытового и промышленного водопотребления приходится на Верхний Дон (до створа г.Лиски), где размещены крупные промышленные центры г.г.Липецк и Воронеж. На Нижнем Дону – от г.Калач на Дону до устья расположены водозаборы крупных городов Ростовской области – Волгодонска, Новочеркасска, Шахт, Ростова, Таганрога, Азова и др. Наиболее крупным водопользователем на этом участке р.Дон является Новочеркасская Грэс. Источниками коммунально бытового водоснабжения (табл. 5.10) на Нижнем Дону является, в основном, речной сток р.р.Дон и Северский Донец, на Верхнем Дону в интересах водоснабжения широко используются подземные воды, за счет которых покрывается весь потребный объем. Таблица 5.54   Забор воды для использования на цели хозяйственно бытового водоснабжения в Рисунок 5.35   Забор воды из поверхностных водных объектов на цели Рисунок 5.36   Забор воды из подземных водных объектов на цели Рисунок 5.38   Забор воды из поверхностных водных объектов на цели Рисунок 5.39   Забор воды из подземных водных объектов на цели Рисунок 5.40   Сброс сточных вод в поверхностные водные объекты после использования на Рисунок 5.41   Забор воды из поверхностных водных объектов на цели Рисунок 5.42   Забор воды из подземных объектов на цели сельскохозяйственного
# ----------------------------------------
# Searching in Manhattan collection...
# ID: e351524f-00bd-4edf-a8f1-1f618ce4989e
# Score: 22.843945
# Content: Продолжение таблицы 5.25
# ID: 7fc3ec77-baae-4600-8f6c-78ad82ba4dfc
# Score: 22.843945
# Content: Продолжение таблицы 5.25
# ID: b622549f-1458-4515-b130-23a517d24459
# Score: 25.53738
# Content: Таблица 5.63   Основные характеристики гидроузлов Рисунок 5.50   Площадь акватории Цимлянского водохранилища при различных отметках у Рисунок 5.51   Забор воды на цели прудового рыбоводства в бассейне р.Дон
# ID: 43b8a8f9-9974-4f02-ab07-f4ff2de0de36
# Score: 25.90926
# Content:
# ID: 957f2bea-c4a6-4cc8-910b-1025215d78ad
# Score: 25.90926
# Content:
# ----------------------------------------

# %% [markdown]
# ### Рабочий хост

# %%
import uuid
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, VectorParams
from sentence_transformers import SentenceTransformer

# Подключение к удалённому серверу Qdrant
client = QdrantClient(url="http://192.168.137.253:6333")

# Модель для векторизации
model_name = "deepvk/USER-bge-m3"
model = SentenceTransformer(model_name)

# Имя коллекции
collection_name = "testing_4_pechora"

# Проверка или создание коллекции
collections = client.get_collections().collections
if not any(c.name == collection_name for c in collections):
    vector_size = model.get_sentence_embedding_dimension()
    client.create_collection(
        collection_name=collection_name,
        vectors_config=VectorParams(size=vector_size, distance="Cosine"),
    )
    print(f"Коллекция '{collection_name}' создана.")
else:
    print(f"Коллекция '{collection_name}' уже существует.")

points = []
for doc in processed_documents:
    vector = model.encode(doc.page_content).tolist()
    point = PointStruct(
        id=str(uuid.uuid4()),
        vector=vector,
        payload={"content": doc.page_content, **doc.metadata},
    )
    points.append(point)


# Загрузка данных
client.upsert(collection_name=collection_name, points=points)
print("Данные успешно добавлены.")
# Out:
# Коллекция 'testing_4_pechora' уже существует.
# Данные успешно добавлены.
